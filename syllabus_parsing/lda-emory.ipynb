# %%
import pandas as pd;
import numpy as np;
import scipy as sp;
import sklearn;
import sys;
from nltk.corpus import stopwords;
import nltk;
from gensim.models import ldamodel
import gensim.corpora;
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer;
from sklearn.decomposition import NMF;
from sklearn.preprocessing import normalize;
from sklearn.decomposition import TruncatedSVD
from gensim import corpora, models
import pyLDAvis
import pyLDAvis.gensim
import copy
import pickle;

# %%
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
import random 
random.seed(13)

#visualization packages
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import seaborn as sns

# %%
import csv
import re
#import spacy
import sys
import requests
import pandas as pd
from io import StringIO
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfpage import PDFTextExtractionNotAllowed
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice
import os
import sys, getopt
import numpy as np
from bs4 import BeautifulSoup
import urllib3
from glob import glob
from string import punctuation

from nltk.corpus import wordnet

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

def find_pdfs():
    list_of_pdfs = []
    pdf_dict = {} # records the indices of the pdfs by year
    for x in range(1990, 2020):
        start = len(list_of_pdfs)
        list_of_pdfs += glob(os.path.join('./EmoryUniversitySyllabi/'+str(x),"*.{}".format('pdf')))
        pdf_dict[x] = list(range(start,len(list_of_pdfs)))
    return list_of_pdfs, pdf_dict

def convert(fname, pages=None):
    """ Function converting pdf to string """
    if not pages:
        pagenums = set()
    else:
        pagenums = set(pages)

    output = StringIO()
    manager = PDFResourceManager()
    converter = TextConverter(manager, output, laparams=LAParams())
    interpreter = PDFPageInterpreter(manager, converter)

    infile = open(fname, 'rb')
    
    try:
        for page in PDFPage.get_pages(infile, pagenums):
            interpreter.process_page(page)
    except PDFTextExtractionNotAllowed:
        print('This pdf won\'t allow text extraction!')
    infile.close()
    converter.close()
    text = output.getvalue()
    output.close
    return strip_punctuation(text)

def word_count(string):
    my_string = string.lower().split()
    my_dict = {}
    for item in my_string:
        if item in my_dict:
            my_dict[item] += 1
        else:
            my_dict[item] = 1

# %%
list_of_pdfs, pdfs_by_year = find_pdfs()
syllabus_string = ''
bag_of_words_all_syllabi = []
corpus = []
# Out:
# ['./EmoryUniversitySyllabi/1990/English Placement Guidelines.pdf',
#  './EmoryUniversitySyllabi/1990/Art105QThurs Fall 16.pdf',
#  './EmoryUniversitySyllabi/1990/050000003281.pdf',
#  './EmoryUniversitySyllabi/1991/050000003288.pdf',
#  './EmoryUniversitySyllabi/1991/050000003287 (1).pdf',
#  './EmoryUniversitySyllabi/1991/050000003283.pdf',
#  './EmoryUniversitySyllabi/1991/050000003282.pdf',
#  './EmoryUniversitySyllabi/1991/050000003286.pdf',
#  './EmoryUniversitySyllabi/1991/050000003287.pdf',
#  './EmoryUniversitySyllabi/1991/050000003285.pdf',
#  './EmoryUniversitySyllabi/1991/050000003284.pdf',
#  './EmoryUniversitySyllabi/1992/050000000757.pdf',
#  './EmoryUniversitySyllabi/1992/050000003289.pdf',
#  './EmoryUniversitySyllabi/1992/050000003303.pdf',
#  './EmoryUniversitySyllabi/1992/050000003317.pdf',
#  './EmoryUniversitySyllabi/1992/050000003329.pdf',
#  './EmoryUniversitySyllabi/1992/050000003301.pdf',
#  './EmoryUniversitySyllabi/1992/050000003315.pdf',
#  './EmoryUniversitySyllabi/1992/050000002817.pdf',
#  './EmoryUniversitySyllabi/1992/050000003314.pdf',
#  './EmoryUniversitySyllabi/1992/050000003328.pdf',
#  './EmoryUniversitySyllabi/1992/050000003304.pdf',
#  './EmoryUniversitySyllabi/1992/050000003310.pdf',
#  './EmoryUniversitySyllabi/1992/050000003311.pdf',
#  './EmoryUniversitySyllabi/1992/050000003305.pdf',
#  './EmoryUniversitySyllabi/1992/050000003313.pdf',
#  './EmoryUniversitySyllabi/1992/050000003307.pdf',
#  './EmoryUniversitySyllabi/1992/050000003529.pdf',
#  './EmoryUniversitySyllabi/1992/050000003306.pdf',
#  './EmoryUniversitySyllabi/1992/050000003312.pdf',
#  './EmoryUniversitySyllabi/1992/050000003547.pdf',
#  './EmoryUniversitySyllabi/1992/050000003529 (1).pdf',
#  './EmoryUniversitySyllabi/1992/050000003323.pdf',
#  './EmoryUniversitySyllabi/1992/050000003294.pdf',
#  './EmoryUniversitySyllabi/1992/050000003295.pdf',
#  './EmoryUniversitySyllabi/1992/050000003530.pdf',
#  './EmoryUniversitySyllabi/1992/050000003322.pdf',
#  './EmoryUniversitySyllabi/1992/050000003308.pdf',
#  './EmoryUniversitySyllabi/1992/050000003320.pdf',
#  './EmoryUniversitySyllabi/1992/050000003334.pdf',
#  './EmoryUniversitySyllabi/1992/050000003297.pdf',
#  './EmoryUniversitySyllabi/1992/050000003335.pdf',
#  './EmoryUniversitySyllabi/1992/050000003321.pdf',
#  './EmoryUniversitySyllabi/1992/050000003325.pdf',
#  './EmoryUniversitySyllabi/1992/050000003331.pdf',
#  './EmoryUniversitySyllabi/1992/050000003319.pdf',
#  './EmoryUniversitySyllabi/1992/050000000758.pdf',
#  './EmoryUniversitySyllabi/1992/050000003292.pdf',
#  './EmoryUniversitySyllabi/1992/050000000759.pdf',
#  './EmoryUniversitySyllabi/1992/050000003318.pdf',
#  './EmoryUniversitySyllabi/1992/050000003332.pdf',
#  './EmoryUniversitySyllabi/1992/050000003326.pdf',
#  './EmoryUniversitySyllabi/1992/050000003327.pdf',
#  './EmoryUniversitySyllabi/1993/050000003538.pdf',
#  './EmoryUniversitySyllabi/1993/050000003544 (1).pdf',
#  './EmoryUniversitySyllabi/1993/050000003528.pdf',
#  './EmoryUniversitySyllabi/1993/050000003375.pdf',
#  './EmoryUniversitySyllabi/1993/050000003361.pdf',
#  './EmoryUniversitySyllabi/1993/050000003567.pdf',
#  './EmoryUniversitySyllabi/1993/050000003566.pdf',
#  './EmoryUniversitySyllabi/1993/050000003374.pdf',
#  './EmoryUniversitySyllabi/1993/050000003404.pdf',
#  './EmoryUniversitySyllabi/1993/050000003362.pdf',
#  './EmoryUniversitySyllabi/1993/050000003376.pdf',
#  './EmoryUniversitySyllabi/1993/050000003389.pdf',
#  './EmoryUniversitySyllabi/1993/050000003558.pdf',
#  './EmoryUniversitySyllabi/1993/050000003564.pdf',
#  './EmoryUniversitySyllabi/1993/050000003565.pdf',
#  './EmoryUniversitySyllabi/1993/050000003559.pdf',
#  './EmoryUniversitySyllabi/1993/050000003388.pdf',
#  './EmoryUniversitySyllabi/1993/050000003377.pdf',
#  './EmoryUniversitySyllabi/1993/050000003405.pdf',
#  './EmoryUniversitySyllabi/1993/050000003363.pdf',
#  './EmoryUniversitySyllabi/1993/050000003367.pdf',
#  './EmoryUniversitySyllabi/1993/050000003398.pdf',
#  './EmoryUniversitySyllabi/1997/050000003691.pdf',
#  './EmoryUniversitySyllabi/1997/050000003446.pdf',
#  './EmoryUniversitySyllabi/1997/050000003678.pdf',
#  './EmoryUniversitySyllabi/1997/050000003687.pdf',
#  './EmoryUniversitySyllabi/1997/050000003902.pdf',
#  './EmoryUniversitySyllabi/1997/050000003686.pdf',
#  './EmoryUniversitySyllabi/1997/050000003679.pdf',
#  './EmoryUniversitySyllabi/1997/050000003453.pdf',
#  './EmoryUniversitySyllabi/1997/050000003447.pdf',
#  './EmoryUniversitySyllabi/1997/050000003457.pdf',
#  './EmoryUniversitySyllabi/1997/050000003682.pdf',
#  './EmoryUniversitySyllabi/1997/050000003912.pdf',
#  './EmoryUniversitySyllabi/1997/050000003913.pdf',
#  './EmoryUniversitySyllabi/1997/050000003683.pdf',
#  './EmoryUniversitySyllabi/1997/050000003898.pdf',
#  './EmoryUniversitySyllabi/1997/050000003456.pdf',
#  './EmoryUniversitySyllabi/1997/050000003454.pdf',
#  './EmoryUniversitySyllabi/1997/050000003680.pdf',
#  './EmoryUniversitySyllabi/1997/050000003455.pdf',
#  './EmoryUniversitySyllabi/1998/050000003470.pdf',
#  './EmoryUniversitySyllabi/1998/050000003464.pdf',
#  './EmoryUniversitySyllabi/1998/050000003698.pdf',
#  './EmoryUniversitySyllabi/1998/050000003465.pdf',
#  './EmoryUniversitySyllabi/1998/050000003471.pdf',
#  './EmoryUniversitySyllabi/1998/050000003459.pdf',
#  './EmoryUniversitySyllabi/1998/050000003467.pdf',
#  './EmoryUniversitySyllabi/1998/050000003498.pdf',
#  './EmoryUniversitySyllabi/1998/050000003704.pdf',
#  './EmoryUniversitySyllabi/1998/050000003499.pdf',
#  './EmoryUniversitySyllabi/1998/050000003472.pdf',
#  './EmoryUniversitySyllabi/1998/050000003466.pdf',
#  './EmoryUniversitySyllabi/1998/050000003462.pdf',
#  './EmoryUniversitySyllabi/1998/050000003489.pdf',
#  './EmoryUniversitySyllabi/1998/050000003700.pdf',
#  './EmoryUniversitySyllabi/1998/050000003701.pdf',
#  './EmoryUniversitySyllabi/1998/050000003488.pdf',
#  './EmoryUniversitySyllabi/1998/050000003477.pdf',
#  './EmoryUniversitySyllabi/1998/050000003463.pdf',
#  './EmoryUniversitySyllabi/1998/050000003475.pdf',
#  './EmoryUniversitySyllabi/1998/050000003461.pdf',
#  './EmoryUniversitySyllabi/1998/050000003500.pdf',
#  './EmoryUniversitySyllabi/1998/050000003702.pdf',
#  './EmoryUniversitySyllabi/1998/050000003460.pdf',
#  './EmoryUniversitySyllabi/1998/050000003474.pdf',
#  './EmoryUniversitySyllabi/1998/050000003349.pdf',
#  './EmoryUniversitySyllabi/1998/050000003356 (1).pdf',
#  './EmoryUniversitySyllabi/1998/050000008180.pdf',
#  './EmoryUniversitySyllabi/1998/050000003360.pdf',
#  './EmoryUniversitySyllabi/1998/050000003348.pdf',
#  './EmoryUniversitySyllabi/1998/bailey_bailey fall 1998.pdf',
#  './EmoryUniversitySyllabi/1998/050000003472 (1).pdf',
#  './EmoryUniversitySyllabi/1998/050000003486 (1).pdf',
#  './EmoryUniversitySyllabi/1998/050000008178.pdf',
#  './EmoryUniversitySyllabi/1998/050000008179.pdf',
#  './EmoryUniversitySyllabi/1998/050000003358.pdf',
#  './EmoryUniversitySyllabi/1998/050000003359.pdf',
#  './EmoryUniversitySyllabi/1998/050000009648.pdf',
#  './EmoryUniversitySyllabi/1998/050000003354.pdf',
#  './EmoryUniversitySyllabi/1998/050000003355.pdf',
#  './EmoryUniversitySyllabi/1998/050000003357.pdf',
#  './EmoryUniversitySyllabi/1998/050000003356.pdf',
#  './EmoryUniversitySyllabi/1998/050000003346.pdf',
#  './EmoryUniversitySyllabi/1998/050000003486 (2).pdf',
#  './EmoryUniversitySyllabi/1998/050000003467 (1).pdf',
#  './EmoryUniversitySyllabi/1998/050000003353.pdf',
#  './EmoryUniversitySyllabi/1998/050000003345.pdf',
#  './EmoryUniversitySyllabi/1998/050000003356 (2).pdf',
#  './EmoryUniversitySyllabi/1998/050000003479.pdf',
#  './EmoryUniversitySyllabi/1998/050000003492.pdf',
#  './EmoryUniversitySyllabi/1998/050000003486.pdf',
#  './EmoryUniversitySyllabi/1998/050000003690.pdf',
#  './EmoryUniversitySyllabi/1998/050000003487.pdf',
#  './EmoryUniversitySyllabi/1998/050000003493.pdf',
#  './EmoryUniversitySyllabi/1998/050000003478.pdf',
#  './EmoryUniversitySyllabi/1998/050000003485.pdf',
#  './EmoryUniversitySyllabi/1998/050000003491.pdf',
#  './EmoryUniversitySyllabi/1998/050000003693.pdf',
#  './EmoryUniversitySyllabi/1998/050000003692.pdf',
#  './EmoryUniversitySyllabi/1998/050000003490.pdf',
#  './EmoryUniversitySyllabi/1998/050000003484.pdf',
#  './EmoryUniversitySyllabi/1998/050000003480.pdf',
#  './EmoryUniversitySyllabi/1998/050000003494.pdf',
#  './EmoryUniversitySyllabi/1998/050000003696.pdf',
#  './EmoryUniversitySyllabi/1998/050000003906.pdf',
#  './EmoryUniversitySyllabi/1998/050000003697.pdf',
#  './EmoryUniversitySyllabi/1998/050000003481.pdf',
#  './EmoryUniversitySyllabi/1998/050000003468.pdf',
#  './EmoryUniversitySyllabi/1998/050000003483.pdf',
#  './EmoryUniversitySyllabi/1998/050000003695.pdf',
#  './EmoryUniversitySyllabi/1998/050000003904.pdf',
#  './EmoryUniversitySyllabi/1998/050000003694.pdf',
#  './EmoryUniversitySyllabi/1998/050000003482.pdf',
#  './EmoryUniversitySyllabi/1998/050000003496.pdf',
#  './EmoryUniversitySyllabi/1998/050000003469.pdf',
#  './EmoryUniversitySyllabi/1999/050000006291.pdf',
#  './EmoryUniversitySyllabi/1999/050000006292.pdf',
#  './EmoryUniversitySyllabi/1999/050000006293.pdf',
#  './EmoryUniversitySyllabi/1999/050000020023.pdf',
#  './EmoryUniversitySyllabi/1999/050000020008.pdf',
#  './EmoryUniversitySyllabi/1999/050000020009.pdf',
#  './EmoryUniversitySyllabi/1999/050000020019.pdf',
#  './EmoryUniversitySyllabi/1999/050000020018.pdf',
#  './EmoryUniversitySyllabi/1999/050000020016.pdf',
#  './EmoryUniversitySyllabi/1999/050000020003.pdf',
#  './EmoryUniversitySyllabi/1999/050000020017.pdf',
#  './EmoryUniversitySyllabi/1999/050000020015.pdf',
#  './EmoryUniversitySyllabi/1999/050000020014.pdf',
#  './EmoryUniversitySyllabi/1999/050000003352.pdf',
#  './EmoryUniversitySyllabi/1999/050000020010.pdf',
#  './EmoryUniversitySyllabi/1999/050000020011.pdf',
#  './EmoryUniversitySyllabi/1999/050000020005.pdf',
#  './EmoryUniversitySyllabi/1999/050000003351.pdf',
#  './EmoryUniversitySyllabi/1999/050000020013.pdf',
#  './EmoryUniversitySyllabi/1999/050000020007.pdf',
#  './EmoryUniversitySyllabi/1999/050000020006.pdf',
#  './EmoryUniversitySyllabi/1999/050000020012.pdf',
#  './EmoryUniversitySyllabi/1999/050000003350.pdf',
#  './EmoryUniversitySyllabi/1999/050000006298.pdf',
#  './EmoryUniversitySyllabi/1999/050000006299.pdf',
#  './EmoryUniversitySyllabi/1999/050000006301.pdf',
#  './EmoryUniversitySyllabi/1999/050000006300.pdf',
#  './EmoryUniversitySyllabi/1999/050000006302.pdf',
#  './EmoryUniversitySyllabi/1999/050000006303.pdf',
#  './EmoryUniversitySyllabi/2000/050000006285.pdf',
#  './EmoryUniversitySyllabi/2000/050000003666.pdf',
#  './EmoryUniversitySyllabi/2000/050000003707.pdf',
#  './EmoryUniversitySyllabi/2000/050000003840.pdf',
#  './EmoryUniversitySyllabi/2000/050000003667.pdf',
#  './EmoryUniversitySyllabi/2000/050000006284.pdf',
#  './EmoryUniversitySyllabi/2000/050000006290.pdf',
#  './EmoryUniversitySyllabi/2000/050000006286.pdf',
#  './EmoryUniversitySyllabi/2000/050000003659.pdf',
#  './EmoryUniversitySyllabi/2000/050000003842.pdf',
#  './EmoryUniversitySyllabi/2000/050000003705.pdf',
#  './EmoryUniversitySyllabi/2000/050000003710.pdf',
#  './EmoryUniversitySyllabi/2000/050000003843.pdf',
#  './EmoryUniversitySyllabi/2000/050000003670.pdf',
#  './EmoryUniversitySyllabi/2000/050000003664.pdf',
#  './EmoryUniversitySyllabi/2000/050000003658.pdf',
#  './EmoryUniversitySyllabi/2000/050000003659 (1).pdf',
#  './EmoryUniversitySyllabi/2000/050000006287.pdf',
#  './EmoryUniversitySyllabi/2000/050000003338.pdf',
#  './EmoryUniversitySyllabi/2000/050000006283.pdf',
#  './EmoryUniversitySyllabi/2000/050000003660.pdf',
#  './EmoryUniversitySyllabi/2000/050000003648.pdf',
#  './EmoryUniversitySyllabi/2000/050000003847.pdf',
#  './EmoryUniversitySyllabi/2000/050000003846.pdf',
#  './EmoryUniversitySyllabi/2000/050000003649.pdf',
#  './EmoryUniversitySyllabi/2000/050000003661.pdf',
#  './EmoryUniversitySyllabi/2000/050000006282.pdf',
#  './EmoryUniversitySyllabi/2000/050000003339.pdf',
#  './EmoryUniversitySyllabi/2000/050000003663.pdf',
#  './EmoryUniversitySyllabi/2000/050000003850.pdf',
#  './EmoryUniversitySyllabi/2000/050000003844.pdf',
#  './EmoryUniversitySyllabi/2000/050000003651 (1).pdf',
#  './EmoryUniversitySyllabi/2000/050000008460.pdf',
#  './EmoryUniversitySyllabi/2000/050000003643.pdf',
#  './EmoryUniversitySyllabi/2000/050000003657.pdf',
#  './EmoryUniversitySyllabi/2000/050000006288.pdf',
#  './EmoryUniversitySyllabi/2001/050000006252.pdf',
#  './EmoryUniversitySyllabi/2001/050000020097.pdf',
#  './EmoryUniversitySyllabi/2001/050000020083.pdf',
#  './EmoryUniversitySyllabi/2001/050000020068.pdf',
#  './EmoryUniversitySyllabi/2001/050000020134.pdf',
#  './EmoryUniversitySyllabi/2001/050000020108.pdf',
#  './EmoryUniversitySyllabi/2001/050000006326.pdf',
#  './EmoryUniversitySyllabi/2001/050000006332.pdf',
#  './EmoryUniversitySyllabi/2001/050000006333.pdf',
#  './EmoryUniversitySyllabi/2001/050000020109.pdf',
#  './EmoryUniversitySyllabi/2001/050000020135.pdf',
#  './EmoryUniversitySyllabi/2001/050000020128 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020121.pdf',
#  './EmoryUniversitySyllabi/2001/050000020069.pdf',
#  './EmoryUniversitySyllabi/2001/050000020082.pdf',
#  './EmoryUniversitySyllabi/2001/050000020096.pdf',
#  './EmoryUniversitySyllabi/2001/050000020280.pdf',
#  './EmoryUniversitySyllabi/2001/050000006253.pdf',
#  './EmoryUniversitySyllabi/2001/050000006251.pdf',
#  './EmoryUniversitySyllabi/2001/050000006279.pdf',
#  './EmoryUniversitySyllabi/2001/050000020080.pdf',
#  './EmoryUniversitySyllabi/2001/050000020094.pdf',
#  './EmoryUniversitySyllabi/2001/050000006344 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020137.pdf',
#  './EmoryUniversitySyllabi/2001/050000020123.pdf',
#  './EmoryUniversitySyllabi/2001/050000006331.pdf',
#  './EmoryUniversitySyllabi/2001/050000006325.pdf',
#  './EmoryUniversitySyllabi/2001/050000006319.pdf',
#  './EmoryUniversitySyllabi/2001/050000020153 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000006318.pdf',
#  './EmoryUniversitySyllabi/2001/050000006324.pdf',
#  './EmoryUniversitySyllabi/2001/050000020122.pdf',
#  './EmoryUniversitySyllabi/2001/050000020136.pdf',
#  './EmoryUniversitySyllabi/2001/050000020095.pdf',
#  './EmoryUniversitySyllabi/2001/050000020081.pdf',
#  './EmoryUniversitySyllabi/2001/050000006278.pdf',
#  './EmoryUniversitySyllabi/2001/050000006268.pdf',
#  './EmoryUniversitySyllabi/2001/050000006254.pdf',
#  './EmoryUniversitySyllabi/2001/050000020278.pdf',
#  './EmoryUniversitySyllabi/2001/050000020085.pdf',
#  './EmoryUniversitySyllabi/2001/050000020091.pdf',
#  './EmoryUniversitySyllabi/2001/050000003970 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020046.pdf',
#  './EmoryUniversitySyllabi/2001/050000020132.pdf',
#  './EmoryUniversitySyllabi/2001/050000020126.pdf',
#  './EmoryUniversitySyllabi/2001/050000006334.pdf',
#  './EmoryUniversitySyllabi/2001/050000006320.pdf',
#  './EmoryUniversitySyllabi/2001/050000006321.pdf',
#  './EmoryUniversitySyllabi/2001/050000006335.pdf',
#  './EmoryUniversitySyllabi/2001/050000020127.pdf',
#  './EmoryUniversitySyllabi/2001/050000020133.pdf',
#  './EmoryUniversitySyllabi/2001/050000020142 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020090.pdf',
#  './EmoryUniversitySyllabi/2001/050000020084.pdf',
#  './EmoryUniversitySyllabi/2001/050000020279.pdf',
#  './EmoryUniversitySyllabi/2001/050000006255.pdf',
#  './EmoryUniversitySyllabi/2001/050000006269.pdf',
#  './EmoryUniversitySyllabi/2001/050000006257.pdf',
#  './EmoryUniversitySyllabi/2001/050000006280.pdf',
#  './EmoryUniversitySyllabi/2001/050000020092.pdf',
#  './EmoryUniversitySyllabi/2001/050000020086.pdf',
#  './EmoryUniversitySyllabi/2001/050000020079.pdf',
#  './EmoryUniversitySyllabi/2001/050000020131.pdf',
#  './EmoryUniversitySyllabi/2001/050000006323.pdf',
#  './EmoryUniversitySyllabi/2001/050000006337.pdf',
#  './EmoryUniversitySyllabi/2001/050000006322.pdf',
#  './EmoryUniversitySyllabi/2001/050000020130.pdf',
#  './EmoryUniversitySyllabi/2001/050000020124.pdf',
#  './EmoryUniversitySyllabi/2001/050000020118.pdf',
#  './EmoryUniversitySyllabi/2001/050000020078.pdf',
#  './EmoryUniversitySyllabi/2001/050000020087.pdf',
#  './EmoryUniversitySyllabi/2001/050000020093.pdf',
#  './EmoryUniversitySyllabi/2001/050000006256.pdf',
#  './EmoryUniversitySyllabi/2001/050000020180.pdf',
#  './EmoryUniversitySyllabi/2001/050000020194.pdf',
#  './EmoryUniversitySyllabi/2001/050000006357 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020143.pdf',
#  './EmoryUniversitySyllabi/2001/050000020157.pdf',
#  './EmoryUniversitySyllabi/2001/050000006345.pdf',
#  './EmoryUniversitySyllabi/2001/050000006351.pdf',
#  './EmoryUniversitySyllabi/2001/050000006350.pdf',
#  './EmoryUniversitySyllabi/2001/050000006344.pdf',
#  './EmoryUniversitySyllabi/2001/050000020156.pdf',
#  './EmoryUniversitySyllabi/2001/050000020142.pdf',
#  './EmoryUniversitySyllabi/2001/050000020195.pdf',
#  './EmoryUniversitySyllabi/2001/050000020181.pdf',
#  './EmoryUniversitySyllabi/2001/050000020220.pdf',
#  './EmoryUniversitySyllabi/2001/050000020197.pdf',
#  './EmoryUniversitySyllabi/2001/050000020183.pdf',
#  './EmoryUniversitySyllabi/2001/050000020154.pdf',
#  './EmoryUniversitySyllabi/2001/050000020140.pdf',
#  './EmoryUniversitySyllabi/2001/050000020168.pdf',
#  './EmoryUniversitySyllabi/2001/050000006352.pdf',
#  './EmoryUniversitySyllabi/2001/050000006346.pdf',
#  './EmoryUniversitySyllabi/2001/050000006347.pdf',
#  './EmoryUniversitySyllabi/2001/050000006353.pdf',
#  './EmoryUniversitySyllabi/2001/050000020169.pdf',
#  './EmoryUniversitySyllabi/2001/050000020141.pdf',
#  './EmoryUniversitySyllabi/2001/050000020155.pdf',
#  './EmoryUniversitySyllabi/2001/050000020182.pdf',
#  './EmoryUniversitySyllabi/2001/050000020196.pdf',
#  './EmoryUniversitySyllabi/2001/050000020192.pdf',
#  './EmoryUniversitySyllabi/2001/050000020186.pdf',
#  './EmoryUniversitySyllabi/2001/050000020179.pdf',
#  './EmoryUniversitySyllabi/2001/050000003978.pdf',
#  './EmoryUniversitySyllabi/2001/050000020151.pdf',
#  './EmoryUniversitySyllabi/2001/050000020145.pdf',
#  './EmoryUniversitySyllabi/2001/050000006357.pdf',
#  './EmoryUniversitySyllabi/2001/050000006343.pdf',
#  './EmoryUniversitySyllabi/2001/050000006342.pdf',
#  './EmoryUniversitySyllabi/2001/050000006356.pdf',
#  './EmoryUniversitySyllabi/2001/050000020144.pdf',
#  './EmoryUniversitySyllabi/2001/050000003979.pdf',
#  './EmoryUniversitySyllabi/2001/050000020178.pdf',
#  './EmoryUniversitySyllabi/2001/050000020187.pdf',
#  './EmoryUniversitySyllabi/2001/050000020218.pdf',
#  './EmoryUniversitySyllabi/2001/050000006334 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000006324 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020191.pdf',
#  './EmoryUniversitySyllabi/2001/050000020146.pdf',
#  './EmoryUniversitySyllabi/2001/050000020152.pdf',
#  './EmoryUniversitySyllabi/2001/050000006356 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000006368.pdf',
#  './EmoryUniversitySyllabi/2001/050000006340.pdf',
#  './EmoryUniversitySyllabi/2001/050000006354.pdf',
#  './EmoryUniversitySyllabi/2001/050000006355.pdf',
#  './EmoryUniversitySyllabi/2001/050000006341.pdf',
#  './EmoryUniversitySyllabi/2001/050000006369.pdf',
#  './EmoryUniversitySyllabi/2001/050000020153.pdf',
#  './EmoryUniversitySyllabi/2001/050000020147.pdf',
#  './EmoryUniversitySyllabi/2001/050000020190.pdf',
#  './EmoryUniversitySyllabi/2001/050000020184.pdf',
#  './EmoryUniversitySyllabi/2001/050000020219.pdf',
#  './EmoryUniversitySyllabi/2001/050000020214.pdf',
#  './EmoryUniversitySyllabi/2001/050000006276 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020189.pdf',
#  './EmoryUniversitySyllabi/2001/050000020162.pdf',
#  './EmoryUniversitySyllabi/2001/050000003977.pdf',
#  './EmoryUniversitySyllabi/2001/050000020176.pdf',
#  './EmoryUniversitySyllabi/2001/050000006364.pdf',
#  './EmoryUniversitySyllabi/2001/050000006370.pdf',
#  './EmoryUniversitySyllabi/2001/050000006358.pdf',
#  './EmoryUniversitySyllabi/2001/050000006359.pdf',
#  './EmoryUniversitySyllabi/2001/050000006365.pdf',
#  './EmoryUniversitySyllabi/2001/050000020177.pdf',
#  './EmoryUniversitySyllabi/2001/050000003976.pdf',
#  './EmoryUniversitySyllabi/2001/050000020163.pdf',
#  './EmoryUniversitySyllabi/2001/050000020188.pdf',
#  './EmoryUniversitySyllabi/2001/Ashmore_auslander fall 2001 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020217.pdf',
#  './EmoryUniversitySyllabi/2001/050000003974.pdf',
#  './EmoryUniversitySyllabi/2001/050000020175.pdf',
#  './EmoryUniversitySyllabi/2001/050000020196 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020149.pdf',
#  './EmoryUniversitySyllabi/2001/050000006367.pdf',
#  './EmoryUniversitySyllabi/2001/Ashmore_auslander fall 2001.pdf',
#  './EmoryUniversitySyllabi/2001/050000006366.pdf',
#  './EmoryUniversitySyllabi/2001/050000020160.pdf',
#  './EmoryUniversitySyllabi/2001/050000020174.pdf',
#  './EmoryUniversitySyllabi/2001/050000003975.pdf',
#  './EmoryUniversitySyllabi/2001/050000020212.pdf',
#  './EmoryUniversitySyllabi/2001/Anderson_Lemons spring 2001.pdf',
#  './EmoryUniversitySyllabi/2001/050000020158.pdf',
#  './EmoryUniversitySyllabi/2001/050000020170.pdf',
#  './EmoryUniversitySyllabi/2001/050000020164.pdf',
#  './EmoryUniversitySyllabi/2001/050000006362.pdf',
#  './EmoryUniversitySyllabi/2001/050000020428.pdf',
#  './EmoryUniversitySyllabi/2001/050000006363.pdf',
#  './EmoryUniversitySyllabi/2001/050000020165.pdf',
#  './EmoryUniversitySyllabi/2001/050000020171.pdf',
#  './EmoryUniversitySyllabi/2001/050000003970.pdf',
#  './EmoryUniversitySyllabi/2001/050000020213.pdf',
#  './EmoryUniversitySyllabi/2001/050000020211.pdf',
#  './EmoryUniversitySyllabi/2001/050000020167.pdf',
#  './EmoryUniversitySyllabi/2001/050000003972.pdf',
#  './EmoryUniversitySyllabi/2001/050000020173.pdf',
#  './EmoryUniversitySyllabi/2001/050000006349.pdf',
#  './EmoryUniversitySyllabi/2001/050000006361.pdf',
#  './EmoryUniversitySyllabi/2001/050000006360.pdf',
#  './EmoryUniversitySyllabi/2001/050000006348.pdf',
#  './EmoryUniversitySyllabi/2001/050000020172.pdf',
#  './EmoryUniversitySyllabi/2001/050000003973.pdf',
#  './EmoryUniversitySyllabi/2001/050000020166.pdf',
#  './EmoryUniversitySyllabi/2001/050000006267.pdf',
#  './EmoryUniversitySyllabi/2001/050000020075.pdf',
#  './EmoryUniversitySyllabi/2001/050000020061.pdf',
#  './EmoryUniversitySyllabi/2001/050000020101.pdf',
#  './EmoryUniversitySyllabi/2001/050000020115.pdf',
#  './EmoryUniversitySyllabi/2001/050000020129.pdf',
#  './EmoryUniversitySyllabi/2001/050000006313.pdf',
#  './EmoryUniversitySyllabi/2001/050000020459.pdf',
#  './EmoryUniversitySyllabi/2001/050000020458.pdf',
#  './EmoryUniversitySyllabi/2001/050000006312.pdf',
#  './EmoryUniversitySyllabi/2001/050000020128.pdf',
#  './EmoryUniversitySyllabi/2001/050000020114.pdf',
#  './EmoryUniversitySyllabi/2001/050000020100.pdf',
#  './EmoryUniversitySyllabi/2001/050000006349 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020074.pdf',
#  './EmoryUniversitySyllabi/2001/050000006266.pdf',
#  './EmoryUniversitySyllabi/2001/050000006272.pdf',
#  './EmoryUniversitySyllabi/2001/050000006264.pdf',
#  './EmoryUniversitySyllabi/2001/050000006270.pdf',
#  './EmoryUniversitySyllabi/2001/050000006258.pdf',
#  './EmoryUniversitySyllabi/2001/050000020089.pdf',
#  './EmoryUniversitySyllabi/2001/050000020062.pdf',
#  './EmoryUniversitySyllabi/2001/050000020076.pdf',
#  './EmoryUniversitySyllabi/2001/050000020116.pdf',
#  './EmoryUniversitySyllabi/2001/050000020102.pdf',
#  './EmoryUniversitySyllabi/2001/050000006339.pdf',
#  './EmoryUniversitySyllabi/2001/050000006311.pdf',
#  './EmoryUniversitySyllabi/2001/050000020103.pdf',
#  './EmoryUniversitySyllabi/2001/050000020117.pdf',
#  './EmoryUniversitySyllabi/2001/050000020142 (2).pdf',
#  './EmoryUniversitySyllabi/2001/050000020077.pdf',
#  './EmoryUniversitySyllabi/2001/050000020063.pdf',
#  './EmoryUniversitySyllabi/2001/050000020088.pdf',
#  './EmoryUniversitySyllabi/2001/050000006259.pdf',
#  './EmoryUniversitySyllabi/2001/050000006271.pdf',
#  './EmoryUniversitySyllabi/2001/050000006265.pdf',
#  './EmoryUniversitySyllabi/2001/050000020156 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000006261.pdf',
#  './EmoryUniversitySyllabi/2001/050000006275.pdf',
#  './EmoryUniversitySyllabi/2001/050000020098.pdf',
#  './EmoryUniversitySyllabi/2001/050000020067.pdf',
#  './EmoryUniversitySyllabi/2001/050000020073.pdf',
#  './EmoryUniversitySyllabi/2001/050000020113.pdf',
#  './EmoryUniversitySyllabi/2001/050000020107.pdf',
#  './EmoryUniversitySyllabi/2001/050000006315.pdf',
#  './EmoryUniversitySyllabi/2001/050000006314.pdf',
#  './EmoryUniversitySyllabi/2001/050000020153 (2).pdf',
#  './EmoryUniversitySyllabi/2001/050000006328.pdf',
#  './EmoryUniversitySyllabi/2001/050000020106.pdf',
#  './EmoryUniversitySyllabi/2001/050000020072.pdf',
#  './EmoryUniversitySyllabi/2001/050000020066.pdf',
#  './EmoryUniversitySyllabi/2001/050000006323 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020099.pdf',
#  './EmoryUniversitySyllabi/2001/050000006274.pdf',
#  './EmoryUniversitySyllabi/2001/050000006260.pdf',
#  './EmoryUniversitySyllabi/2001/050000006276.pdf',
#  './EmoryUniversitySyllabi/2001/050000006262.pdf',
#  './EmoryUniversitySyllabi/2001/050000020194 (1).pdf',
#  './EmoryUniversitySyllabi/2001/050000020070.pdf',
#  './EmoryUniversitySyllabi/2001/050000020064.pdf',
#  './EmoryUniversitySyllabi/2001/050000020138.pdf',
#  './EmoryUniversitySyllabi/2001/050000020104.pdf',
#  './EmoryUniversitySyllabi/2001/050000020110.pdf',
#  './EmoryUniversitySyllabi/2001/050000020460.pdf',
#  './EmoryUniversitySyllabi/2001/050000006317.pdf',
#  './EmoryUniversitySyllabi/2001/050000020111.pdf',
#  './EmoryUniversitySyllabi/2001/050000020105.pdf',
#  './EmoryUniversitySyllabi/2001/050000020139.pdf',
#  './EmoryUniversitySyllabi/2001/050000020065.pdf',
#  './EmoryUniversitySyllabi/2001/050000020071.pdf',
#  './EmoryUniversitySyllabi/2001/050000006263.pdf',
#  './EmoryUniversitySyllabi/2001/050000006277.pdf',
#  './EmoryUniversitySyllabi/2002/050000021148.pdf',
#  './EmoryUniversitySyllabi/2002/050000021174.pdf',
#  './EmoryUniversitySyllabi/2002/050000023763.pdf',
#  './EmoryUniversitySyllabi/2002/050000023777.pdf',
#  './EmoryUniversitySyllabi/2002/050000021160.pdf',
#  './EmoryUniversitySyllabi/2002/050000021202.pdf',
#  './EmoryUniversitySyllabi/2002/050000021216.pdf',
#  './EmoryUniversitySyllabi/2002/050000021217.pdf',
#  './EmoryUniversitySyllabi/2002/050000021203.pdf',
#  './EmoryUniversitySyllabi/2002/050000021161.pdf',
#  './EmoryUniversitySyllabi/2002/050000023776.pdf',
#  './EmoryUniversitySyllabi/2002/050000023762.pdf',
#  './EmoryUniversitySyllabi/2002/050000021149.pdf',
#  './EmoryUniversitySyllabi/2002/050000023140.pdf',
#  './EmoryUniversitySyllabi/2002/050000021794.pdf',
#  './EmoryUniversitySyllabi/2002/050000021179.pdf',
#  './EmoryUniversitySyllabi/2002/050000023752.pdf',
#  './EmoryUniversitySyllabi/2002/050000021145.pdf',
#  './EmoryUniversitySyllabi/2002/050000021151.pdf',
#  './EmoryUniversitySyllabi/2002/050000021186.pdf',
#  './EmoryUniversitySyllabi/2002/050000021192.pdf',
#  './EmoryUniversitySyllabi/2003/050000024781.pdf',
#  './EmoryUniversitySyllabi/2003/050000024756.pdf',
#  './EmoryUniversitySyllabi/2003/050000024742.pdf',
#  './EmoryUniversitySyllabi/2003/050000028178.pdf',
#  './EmoryUniversitySyllabi/2003/050000028408.pdf',
#  './EmoryUniversitySyllabi/2003/050000024554.pdf',
#  './EmoryUniversitySyllabi/2003/050000024540.pdf',
#  './EmoryUniversitySyllabi/2003/050000028352.pdf',
#  './EmoryUniversitySyllabi/2003/050000024568.pdf',
#  './EmoryUniversitySyllabi/2003/050000028346.pdf',
#  './EmoryUniversitySyllabi/2003/050000028420.pdf',
#  './EmoryUniversitySyllabi/2003/050000028347.pdf',
#  './EmoryUniversitySyllabi/2003/050000028421.pdf',
#  './EmoryUniversitySyllabi/2003/050000024569.pdf',
#  './EmoryUniversitySyllabi/2003/050000028353.pdf',
#  './EmoryUniversitySyllabi/2003/050000024541.pdf',
#  './EmoryUniversitySyllabi/2003/050000028409.pdf',
#  './EmoryUniversitySyllabi/2003/050000024555.pdf',
#  './EmoryUniversitySyllabi/2003/050000028179.pdf',
#  './EmoryUniversitySyllabi/2003/050000024743.pdf',
#  './EmoryUniversitySyllabi/2003/050000024757.pdf',
#  './EmoryUniversitySyllabi/2003/050000024780.pdf',
#  './EmoryUniversitySyllabi/2003/050000024794.pdf',
#  './EmoryUniversitySyllabi/2003/050000024782.pdf',
#  './EmoryUniversitySyllabi/2003/050000024741.pdf',
#  './EmoryUniversitySyllabi/2003/050000024755.pdf',
#  './EmoryUniversitySyllabi/2003/050000024769.pdf',
#  './EmoryUniversitySyllabi/2003/050000024580.pdf',
#  './EmoryUniversitySyllabi/2003/050000024543.pdf',
#  './EmoryUniversitySyllabi/2003/050000024557.pdf',
#  './EmoryUniversitySyllabi/2003/050000028423.pdf',
#  './EmoryUniversitySyllabi/2003/050000028345.pdf',
#  './EmoryUniversitySyllabi/2003/050000028351.pdf',
#  './EmoryUniversitySyllabi/2003/050000028350.pdf',
#  './EmoryUniversitySyllabi/2003/050000028422.pdf',
#  './EmoryUniversitySyllabi/2003/050000028344.pdf',
#  './EmoryUniversitySyllabi/2003/050000024556.pdf',
#  './EmoryUniversitySyllabi/2003/050000024542.pdf',
#  './EmoryUniversitySyllabi/2003/050000024768.pdf',
#  './EmoryUniversitySyllabi/2003/050000024754.pdf',
#  './EmoryUniversitySyllabi/2003/050000024740.pdf',
#  './EmoryUniversitySyllabi/2003/050000024783.pdf',
#  './EmoryUniversitySyllabi/2003/bailey_chen_iskra fall 2003 (1).pdf',
#  './EmoryUniversitySyllabi/2003/050000024787.pdf',
#  './EmoryUniversitySyllabi/2003/050000024793.pdf',
#  './EmoryUniversitySyllabi/2003/050000024778.pdf',
#  './EmoryUniversitySyllabi/2003/050000024744.pdf',
#  './EmoryUniversitySyllabi/2003/050000024750.pdf',
#  './EmoryUniversitySyllabi/2003/050000028340.pdf',
#  './EmoryUniversitySyllabi/2003/050000028354.pdf',
#  './EmoryUniversitySyllabi/2003/050000024546.pdf',
#  './EmoryUniversitySyllabi/2003/050000024552.pdf',
#  './EmoryUniversitySyllabi/2003/Bailey_chen spring 2003.pdf',
#  './EmoryUniversitySyllabi/2003/050000024553.pdf',
#  './EmoryUniversitySyllabi/2003/050000024547.pdf',
#  './EmoryUniversitySyllabi/2003/050000028355.pdf',
#  './EmoryUniversitySyllabi/2003/050000028341.pdf',
#  './EmoryUniversitySyllabi/2003/050000024751.pdf',
#  './EmoryUniversitySyllabi/2003/050000024745.pdf',
#  './EmoryUniversitySyllabi/2003/050000024779.pdf',
#  './EmoryUniversitySyllabi/2003/050000024792.pdf',
#  './EmoryUniversitySyllabi/2003/050000024786.pdf',
#  './EmoryUniversitySyllabi/2003/050000028180.pdf',
#  './EmoryUniversitySyllabi/2003/050000024790.pdf',
#  './EmoryUniversitySyllabi/2003/050000024784.pdf',
#  './EmoryUniversitySyllabi/2003/050000024753.pdf',
#  './EmoryUniversitySyllabi/2003/050000024747.pdf',
#  './EmoryUniversitySyllabi/2003/050000028357.pdf',
#  './EmoryUniversitySyllabi/2003/050000024579.pdf',
#  './EmoryUniversitySyllabi/2003/050000028343.pdf',
#  './EmoryUniversitySyllabi/2003/050000024551.pdf',
#  './EmoryUniversitySyllabi/2003/050000028419.pdf',
#  './EmoryUniversitySyllabi/2003/050000024545.pdf',
#  './EmoryUniversitySyllabi/2003/050000024196.pdf',
#  ...]

# %%
#Converting pdf to string
for pdf in list_of_pdfs:
    syllabus_string = convert(pdf)
    corpus.append(syllabus_string)
    bag_of_words_one_syllabus = word_count(syllabus_string)
    bag_of_words_all_syllabi.append(bag_of_words_one_syllabus)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-534a5eeb4f37> in <module>()
#       1 #Converting pdf to string
#       2 for pdf in list_of_pdfs:
# ----> 3     syllabus_string = convert(pdf)
#       4     corpus.append(syllabus_string)
#       5     bag_of_words_one_syllabus = word_count(syllabus_string)
#
# <ipython-input-8-2a771efd433b> in convert(fname, pages)
#      55     try:
#      56         for page in PDFPage.get_pages(infile, pagenums):
# ---> 57             interpreter.process_page(page)
#      58     except PDFTextExtractionNotAllowed:
#      59         print('This pdf won\'t allow text extraction!')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pdfminer/pdfinterp.py in process_page(self, page)
#     850             ctm = (1, 0, 0, 1, -x0, -y0)
#     851         self.device.begin_page(page, ctm)
# --> 852         self.render_contents(page.resources, page.contents, ctm=ctm)
#     853         self.device.end_page(page)
#     854         return
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pdfminer/pdfinterp.py in render_contents(self, resources, streams, ctm)
#     860         log.info('render_contents: resources=%r, streams=%r, ctm=%r',
#     861                  resources, streams, ctm)
# --> 862         self.init_resources(resources)
#     863         self.init_state(ctm)
#     864         self.execute(list_value(streams))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pdfminer/pdfinterp.py in init_resources(self, resources)
#     360                         objid = spec.objid
#     361                     spec = dict_value(spec)
# --> 362                     self.fontmap[fontid] = self.rsrcmgr.get_font(objid, spec)
#     363             elif k == 'ColorSpace':
#     364                 for (csid, spec) in six.iteritems(dict_value(v)):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pdfminer/pdfinterp.py in get_font(self, objid, spec)
#     195             elif subtype == 'TrueType':
#     196                 # TrueType Font
# --> 197                 font = PDFTrueTypeFont(self, spec)
#     198             elif subtype == 'Type3':
#     199                 # Type3 Font
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pdfminer/pdffont.py in __init__(self, rsrcmgr, spec)
#     586             widths = list_value(spec.get('Widths', [0]*256))
#     587             widths = dict((i+firstchar, w) for (i, w) in enumerate(widths))
# --> 588         PDFSimpleFont.__init__(self, descriptor, widths, spec)
#     589         if 'Encoding' not in spec and 'FontFile' in descriptor:
#     590             # try to recover the missing encoding info from the font file.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pdfminer/pdffont.py in __init__(self, descriptor, widths, spec)
#     545             name = literal_name(encoding.get('BaseEncoding', LITERAL_STANDARD_ENCODING))
#     546             diff = list_value(encoding.get('Differences', []))
# --> 547             self.cid2unicode = EncodingDB.get_encoding(name, diff)
#     548         else:
#     549             self.cid2unicode = EncodingDB.get_encoding(literal_name(encoding))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pdfminer/encodingdb.py in get_encoding(klass, name, diff)
#      59                 elif isinstance(x, PSLiteral):
#      60                     try:
# ---> 61                         cid2unicode[cid] = name2unicode(x.name)
#      62                     except KeyError:
#      63                         pass
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pdfminer/encodingdb.py in name2unicode(name)
#      19     if not m:
#      20         raise KeyError(name)
# ---> 21     return six.unichr(int(m.group(0)))
#      22
#      23
#
# ValueError: chr() arg not in range(0x110000)

# %%
len(corpus)
corpus = corpus[:3030] + [' '] + corpus[3030:]

# %%
for pdf in list_of_pdfs[3031:]:
    syllabus_string = convert(pdf)
    corpus.append(syllabus_string)
    bag_of_words_one_syllabus = word_count(syllabus_string)
    bag_of_words_all_syllabi.append(bag_of_words_one_syllabus)

# %%
len(corpus)
# Out:
# 4544

# %%
corpus[3029]
# Out:
# 'FSOX 270 Introduction to Film Studies \nFall 2011 Oxford College \n \nTuesdays Thursdays 1000 am1115 pm East Village Alpha 157 \nMandatory Screening Thursdays 300600 pm East Village Alpha 157 \n \nInstructor Matthew Kiesner MA \nEmail Mkiesneemoryedu \nOffice Hours TuThurs 100245 Humanities 205 office phone 44605 \n \nTextbook Phillips William H Film An Introduction fourth Edition 2009 \n \nThe moving image is an everincreasing presence in our lives Technology has \nbroken down the barriers of production and exhibition Understanding the \ncinematic art is now more important than ever This course teaches students the \nfundamentals of film form allowing students to better understand analyze and \ncreate films The course approaches a variety of film types through historical \neconomic aesthetic and social contexts in order to build a student’s general \nknowledge about films and filmmaking  \n \nGrading and Assignments \nThe course is out of 100 points and the total will correlate with to a standard \nacademic grading scale A93 A90 B87 B83 B80 \n \nAttendance and Participation 10 points \nAttendance is mandatory for all scheduled classes and screenings Attendance \nwill be taken at all class meetings I allow one absence but any additional \nunexcused absences will reduce your attendance grade one point Excused \nabsences are allowed for medical legal or religious reasons  \n \nWeekly Responses 15 points \nStudents need to send an email response about each screening Each response \nis due by noon on Friday after each screening The responses should be about \nhow the film connects with the weekly topic and readings and use relevant \nexamples \n \nIntroductory paper 5 points \nA three page paper on a film of your choice The paper should include a \nsummary and an analysis if an important scene of your choosing \n \nFinal Paper 20 points \nThe term paper is five to seven pages on a film of your choice This paper must \nthesis oriented with a strong argument and effective examples \n \nMidterm Exam and Final Exam 25 points each \n \n\n\x0cMy grading will use the  system on the final grade for accuracy Late work will \nnot be accepted unless you provide a letter of explanation from Oxford faculty \nandor administration  \n \nCitations and Plagiarism In terms of film studies common knowledge extends \nto basic information about a film including its year director and cast However \nany plot summary of a film is the unique work of the author and needs citation \nUsing Internet sources in responses without citation will count as plagiarism This \nincludes descriptive phrases and information beyond the scope of inclass \nlectures Using sources without citation in responses or papers will lead to failure \nof the assignment and may necessitate an incident report to the Honor Council \n \nElectronic Device Policy Use of Laptops tablets and smart phones is not \npermitted during lectures or screenings Cell phones must be silenced during \nlectures and screenings Checking of messages and texting is not permitted All \nheadphones ear buds and Bluetooth headsets must be removed Failure to \nrespect these policies will lead to a point loss on your attendance and \nparticipation grade of up to five points  \n \nPlease Note that this course will show films stills and clips that include nudity \nexplicit sexuality vulgar language and graphic violence that some students may \nfind troubling Your enrollment in this course indicates your awareness of this and \nyour willingness to approach these films andor images in an adult critical \nmanner  \n \nWEEKLY SCHEDULE \n \n825 \nIntroduction to course and film production \nPhillips appendix 694701 \nScreening The Royal Tenenbaums Wes Anderson 2001 \n \n83091 \nMiseenscene \nPhillips Introduction Ch One  \nRausch “George Melies and the Artificially Arranged Scene” on reserve  \nScreening Seconds John Frankenheimer 1966 \n \n9698 \nCinematography \nPhillips Ch Two \nRausch Ch Fifteen  \nScreening The Lime ...

# %%
oldcorpus = copy.deepcopy(corpus)

# %%
startindex = pdfs_by_year[2001][0]

# %%
corpus = corpus[startindex:]

# %%
len(corpus)
# Out:
# 4102

# %% [markdown]
# # Cleaning

# %%
from nltk.corpus import words
from nltk.corpus import stopwords
 

allEnglishWords = set(words.words())
stopwordsList = set(stopwords.words('english'))

def clean_doc(doc, english = False, return_list = False, stopwords = False):
    listOfWords = re.findall(r'[^\d\W]{2,}', doc)
    listOfWords = [word.lower() for word in listOfWords if len(word) > 2]
    if english:
        listOfWords = [word for word in listOfWords if word in allEnglishWords]
    if stopwords:
        listOfWords = [word for word in listOfWords if word not in stopwordsList]
    if return_list:
        return listOfWords
    else:
        return " ".join(listOfWords)

# %%
cleaned_corpus = [clean_doc(doc, return_list = True, stopwords = True) for doc in corpus]

# %%
cleaned_corpus_1 = [clean_doc(doc, english = True, return_list = True, stopwords = True) for doc in corpus]

# %%
cleaned_corpus_2 = [clean_doc(doc, english = True, return_list = False, stopwords = True) for doc in corpus]

# %%
#cleaned_corpus_3 = [clean_doc(doc, english = False, return_list = False, stopwords = True) for doc in corpus]

# %%
#cleaned_corpus_4 = [clean_doc(doc, english = False, return_list = True, stopwords = True) for doc in corpus]

# %%
cleaned_corpus_2[1]
# Out:
# 'art drawing painting fall class time office hall office mon studio course description art studio course descriptive drawing painting render interpret visually artist foci studio exploration formal art relation strong value space form expression study aesthetic physical psychological chroma color theory project designed allow artist acquire refine technical conceptual necessary serious artistic course performance upon completion course able demonstrate understanding formal line shape value texture color relate visual organization harmony balance rhythm repetition movement dominance proportion artist works independently explore master formal art relation strong aesthetically solve successfully work dry wet media proficiently render space atmospheric intuitive perspective color chiaroscuro artist independently develop necessary convey aesthetic produce visual explore various strong explore subject matter well subject meaning rubric artist develop unique independent vision symbolism iconography develop criteria successfully analyze critically discuss work objective crucial artist must learn independently analyze art articulate critical thinking process aesthetic student evaluation grading six worth composition understanding assigned technique craftsmanship value handling media comprehension color theory creativity also receive performance participation formal final grade average following grading system class attendance every absence excess one result lowering final average five responsible work absence must present present week late accepted without penalty one letter grade per day late final critique cannot turned late academic integrity essential college honor code violation may result failure class suspension dismissal college course schedule introduction course overview discussion sept sept project two still life explore various drawing chiaroscuro color theory project drawing technique willow compressed black charcoal graphite white paper project continued project additive drawing technique white paper complimentary color painting demonstration primary color assignment red yellow blue acrylic paint board sept project subtractive drawing technique classical drapery study willow compressed charcoal white paper secondary color assignment orange green violet acrylic paint board due project primary color sept project realism abstraction drawing still life explore realistic rendering abstract expressiveness realistic drawing tricolored conte tonal paper abstract drawing acrylic split complimentary color scheme artist choice due project secondary color sept project continued working critique tertiary color assignment red orange yellow green blue violet acrylic paint board critique project project project project color wheel value intensity scales acrylic paint board project continued project single object big little two explore scale monumentality compare contrast flat acrylic paint canvas color complimentary split complimentary triad artist choice object due project project continued working critique project still life chiaroscuro canvas artist choice color analogous formal studio independent work project project continued working critique course review due project thanksgiving holiday final critique choice individual portfolio review upon request art class studio art studio covered lab fee fee must fee may cash opus account choose purchase art independently must studio student board pad soft art white drawing kit graphite compressed charcoal conte black sanguine alpha color white alpha color black drawing paper six white various acrylic paint set titanium white tube cadmium yellow tube brushes paint palette paint various sizes paper set'

# %% [markdown]
# # NMF

# %%
corpus_used = cleaned_corpus_2
len(corpus_used)
# Out:
# 4102

# %%
vectorizer = CountVectorizer(analyzer='word', stop_words='english', lowercase=True, token_pattern=r'[^\d\W]{2,}', ngram_range = (1,1), max_df = 0.9);
x_counts = vectorizer.fit_transform(corpus_used);

# %%
transformer = TfidfTransformer(smooth_idf=True);
x_tfidf = transformer.fit_transform(x_counts);

# %%
xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

# %%
def get_nmf_topics(model, num_topics, top_n_words):
    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(num_topics):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-top_n_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
num_topics = 50
nmf_model = NMF(n_components=num_topics, init='nndsvd')
nmf_model.fit(xtfidf_norm)
nmf_embedding = nmf_model.transform(xtfidf_norm)
nmf_embedding = (nmf_embedding - nmf_embedding.mean(axis=0))/nmf_embedding.std(axis=0)

# %%
get_nmf_topics(nmf_model, num_topics,10)
# Out:
#    Topic # 01  Topic # 02       Topic # 03    Topic # 04     Topic # 05  \
# 0       class         lab         calculus           cap           math
# 1    religion      report          gateway         class            wed
# 2     reading  experiment             test         final       rational
# 3  discussion  laboratory              odd      workbook      quadratic
# 4       paper        data          student           pop      provision
# 5   religious      safety    trigonometric     professor            mon
# 6       study    notebook           series         event        algebra
# 7         new   chemistry           review  conversation      algebraic
# 8     journal     portion  differentiation      speaking  trigonometric
# 9       group        quiz       derivative        cantar         retest
#
#      Topic # 06   Topic # 07 Topic # 08 Topic # 09 Topic # 10     ...       \
# 0       physics         sept    chapter     lesson       swim     ...
# 1          test  communicate       week   dialogue       pool     ...
# 2        subset      biology   economic   workbook   swimming     ...
# 3     weighting         team      march  character      water     ...
# 4    strengthen        topic       exam   mandarin   survival     ...
# 5         broad         date     policy    sitting     stroke     ...
# 6      thirteen          ons     market   practice       test     ...
# 7          exam     contents     demand     silent      crawl     ...
# 8          math         fall     supply      cheng     safety     ...
# 9  prerequisite    organized  numerical       test    bobbing     ...
#
#    Topic # 41   Topic # 42    Topic # 43    Topic # 44   Topic # 45  \
# 0        mitt        drill        devoir   mathematics      theater
# 1      german      chapter         salon        linear         play
# 2       thema   declension   seventeenth      calculus  performance
# 3         die         odds         moyen          work   theatrical
# 4        oral      passive           dor       problem        class
# 5  vocabulary  subjunctive    classicism  mathematical   production
# 6    language       active           rid       student         live
# 7       class    imperfect    aesthetics      homework        stage
# 8   portfolio         quiz  civilization       algebra        drama
# 9     student      perfect         allow        theory       acting
#
#    Topic # 46  Topic # 47     Topic # 48 Topic # 49   Topic # 50
# 0     pollock     geology     philosophy       unit   literature
# 1   companion         yes  philosophical   exercise  examination
# 2    research     lecture         ethics  dimension        march
# 3   political         lab        reverse  continued        essay
# 4        data     chapter            ken    disease     composed
# 5    analysis  laboratory          human       week      factual
# 6     science       earth       religion   wellness       assume
# 7  regression     weather    philosopher    walking     literary
# 8  statistics    geologic        ethical      ozone        class
# 9  hypotheses  weathering        thought     health    carpenter
#
# [10 rows x 50 columns]

# %%
get_nmf_topics(nmf_model, num_topics,10) # 100 topics on NMF looks best
# Out:
#    Topic # 01  Topic # 02  Topic # 03    Topic # 04 Topic # 05    Topic # 06  \
# 0  accounting         lab         tai           cap        mon       physics
# 1   financial      report       skill         class        wed          test
# 2    homework  experiment         chi         final       math        subset
# 3        exam  laboratory    practice      workbook      class     weighting
# 4    business        data        form           pop  provision    strengthen
# 5       class      safety     lecture     professor  quadratic          math
# 6        cash    notebook        test  conversation   rational         broad
# 7      assets   chemistry        gong         event     retest      thirteen
# 8        time     portion        yang      speaking      group          exam
# 9      equity        quiz  meditation        cantar    radical  prerequisite
#
#    Topic # 07 Topic # 08 Topic # 09 Topic # 10     ...       Topic # 91  \
# 0        sept    chapter     lesson       swim     ...             week
# 1        team    lecture   dialogue      water     ...           market
# 2         ons      class   workbook   survival     ...      competition
# 3     biology        sec  character   swimming     ...           demand
# 4   continued  continued   mandarin      crawl     ...           supply
# 5       topic      study    sitting     stroke     ...        economics
# 6  discipline   material     silent     safety     ...        oligopoly
# 7        fall       exam      cheng    bobbing     ...            trade
# 8     concept       read       test       test     ...             exam
# 9        math    student       oral   treading     ...         economic
#
#   Topic # 92    Topic # 93  Topic # 94     Topic # 95   Topic # 96  \
# 0      tarea          walk      soccer           mart      reprise
# 1     examen       walking       coach           sett         lire
# 2       oral       fitness     student       language  composition
# 3     enlace      wellness  basketball          video      version
# 4    proximo         class       sport     vocabulary         pour
# 5        lab  successfully        game       speaking        tutor
# 6       leer         score      appeal           oral       examen
# 7       exam       student       skill      listening         quiz
# 8       para      complete        yard  comprehension      feuille
# 9   homework          earn    trapping       homework     monsieur
#
#    Topic # 97     Topic # 98   Topic # 99 Topic # 100
# 0  giftedness       economic          odd        hike
# 1  discussion           week       series  wilderness
# 2      gifted      aggregate         test        aide
# 3  creativity      inflation      gateway        trip
# 4        team        economy     infinite     outdoor
# 5    research         policy        power       trail
# 6  psychology   unemployment        polar     cooking
# 7       class         income       review    lifetime
# 8     leading          march  integration   equipment
# 9  leadership  international     calculus       route
#
# [10 rows x 100 columns]

# %%
get_nmf_topics(nmf_model, num_topics,10)
# Out:
#       Topic # 01  Topic # 02  Topic # 03    Topic # 04    Topic # 05  \
# 0          class         lab         tai           cap          math
# 1           time      safety       skill         final     quadratic
# 2            day  laboratory         chi      workbook      rational
# 3           late  experiment    practice           pop     provision
# 4       material      report        form         class        retest
# 5           come        quiz     lecture     professor     algebraic
# 6  participation    notebook        test  conversation  trigonometry
# 7            use      manual        gong         event       algebra
# 8          grade        zero        yang      speaking   probability
# 9          bring  evaluation  meditation        cantar   mathematics
#
#    Topic # 06  Topic # 07    Topic # 08 Topic # 09     Topic # 10     ...      \
# 0     physics        sept       chapter     lesson       survival     ...
# 1        test        team       lecture   dialogue           swim     ...
# 2      subset         ons         class   workbook          water     ...
# 3   weighting     biology           sec  character         rescue     ...
# 4  strengthen       topic          exam   mandarin        bobbing     ...
# 5       broad  discipline    dissection      cheng       swimming     ...
# 6    thirteen   continued          read       test       treading     ...
# 7        exam     concept  introduction      level  participation     ...
# 8     logical        fall         break       oral           clad     ...
# 9        math        room        change     stroke          crawl     ...
#
#     Topic # 191     Topic # 192    Topic # 193 Topic # 194    Topic # 195  \
# 0         group      experiment      happiness     geology        outdoor
# 1       project          report        paradox         yes  participation
# 2    dramaturgy            data      adversity     lecture       climbing
# 3  presentation    spectroscopy       reliably       earth        cooking
# 4       journal      instrument         growth         lab          class
# 5          work  chromatography      gratitude  weathering     connection
# 6      spoonful         unknown  advertisement  laboratory         attire
# 7    assignment        notebook            awe    geologic         safety
# 8           led         mixture         virtue     igneous   unauthorized
# 9        gender             set       progress   tectonics         proper
#
#   Topic # 196    Topic # 197   Topic # 198 Topic # 199 Topic # 200
# 0  leadership         examen       seminar     writing    homework
# 1      ethics           oral         paper    research     costing
# 2     leading           gent     shamanism       essay        turn
# 3  discussion    composition      dynamics        life  conference
# 4     servant       workbook           soc        oral    assigned
# 5     summary       speaking  predeparture  assignment  managerial
# 6       essay          conte        depart  nonfiction  accounting
# 7       class  comprehension  spirituality      memoir       class
# 8      leader       revision       ethical         say         bus
# 9        team  participation       meeting        read        time
#
# [10 rows x 200 columns]

# %% [markdown]
# # LDA

# %%
corpus_used = cleaned_corpus_1

# %%
id2word = gensim.corpora.Dictionary(corpus_used);
id2word

# %%
bow_corpus = [id2word.doc2bow(doc) for doc in corpus_used]

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
num_topics = 100

# %%
lda_tfidf = gensim.models.ldamodel.LdaModel(corpus_tfidf, num_topics=num_topics, id2word=id2word, alpha='auto', passes=50, random_state = 42)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
def get_lda_topics(model, num_topics):
    word_dict = {};
    for i in range(num_topics):
        words = model.show_topic(i, topn = 20);
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words];
    return pd.DataFrame(word_dict);

# %%
get_lda_topics(lda_tfidf, num_topics)# with auto, 50 passes
# Out:
#       Topic # 01     Topic # 02     Topic # 03   Topic # 04      Topic # 05  \
# 0    paleolithic  propositional          revel       tennis      annotation
# 1     fourteenth        proving       colonial    admission        duration
# 2   truthtelling       cogently            gay       racket      employment
# 3        brother         landau         autism      singles            nick
# 4      neolithic           mart            tea        excel  constitutional
# 5          proto        calculi        virtual     unsuited         gallery
# 6   pharmacology        amplify        slavery          net             oil
# 7       football         proved         nation      scoring         beneath
# 8     republican          prove        decline  frustration            muse
# 9       imperial     exhaustive      scripture     endeavor        escalate
# 10          lucy      wondering         temple    biosphere         supreme
# 11         spite     insightful         coward          wet         liberty
# 12         birch    complicated      quarterly   incredibly           mason
# 13       trigger       duration           wang        court         visible
# 14     memoirist            cap           dick     nitrogen           court
# 15    popularity            che      sectional   phosphorus            loan
# 16       whitten            dal          awake  reclamation            laid
# 17     tarnation          proof  impermissible        deuce        district
# 18       painful     presumable          canon   aggressive          becker
# 19        healer         outset          tally       league         privacy
#
#          Topic # 06      Topic # 07      Topic # 08         Topic # 09  \
# 0     metamorphoses            golf        likewise                tai
# 1           reliant            mill     homogeneous                chi
# 2           condone  utilitarianism  unsatisfactory            workout
# 3           deathly          morals         nucleus              arrow
# 4           figured       shamanism          solely  cardiorespiratory
# 5           chamber       grounding      orthogonal               gong
# 6           vitamin            meta       nonlinear        interviewee
# 7   instrumentation       genealogy    undetermined      indeterminate
# 8        instrument        chipping          sphere       prescription
# 9           solvent    predeparture          soviet             enlace
# 10         compiler           glory           probe            dietary
# 11          overlap         persist          colley              barth
# 12      abstraction     dynamically        resemble             lonely
# 13       naturalist           fight     contributor              funny
# 14           nickel       clockwork      habitually               lama
# 15             salt           dingy      absolutism           graceful
# 16             beer           almon         pianist           shepherd
# 17   professionally    incompatible   choreographic             browse
# 18      underlining           oxbow        ordinary              skill
# 19       programmer       detective          gladly           punching
#
#        Topic # 10      ...          Topic # 91      Topic # 92     Topic # 93  \
# 0        rhythmic      ...             candler             cap     governance
# 1          overly      ...             geology          potter       deletion
# 2            hart      ...               earth        sorcerer     restricted
# 3        scissors      ...            geologic    compensation         crises
# 4           kerry      ...        notification          roster       nowadays
# 5          lawyer      ...               plate           ender         belong
# 6             flu      ...             igneous     discourtesy         import
# 7      informally      ...           tectonics       concealed          steep
# 8      intolerant      ...         sedimentary            ante      strenuous
# 9         teenage      ...         metamorphic           frase      monologue
# 10      courtroom      ...            humanism        quarters      proximity
# 11        lactose      ...             mineral        exertion  imaginatively
# 12  typographical      ...          weathering         upstate      intuition
# 13        slashed      ...            confront           maize         dollar
# 14        verdict      ...                 yes           viral     commercial
# 15           momo      ...             coastal          heyday           levy
# 16         cheese      ...          glaciation            coli    superlative
# 17          infer      ...         deformation        invasion       bridging
# 18       lifeline      ...                soil          dosage         costly
# 19          swine      ...            communal  nondisjunction     appraising
#
#          Topic # 94  Topic # 95     Topic # 96      Topic # 97   Topic # 98  \
# 0            refute      studio         prince             doc          ode
# 1         comprised     drawing  interpersonal   administrator         poet
# 2          fidelity    painting      conducive        annotate      chimney
# 3   institutionally       color      leviathan         soprano    innocence
# 4            annals        para         dining          deceit         lamb
# 5           dispute        leer           spur        brochure      sweeper
# 6       destruction    charcoal     antibiotic     attributive    beauteous
# 7              otto     texture           ease        genitive   melancholy
# 8          temporal       paint        imagine          wetter   churchyard
# 9       inquisition      render     touchstone           lover      skylark
# 10       confession  repetition        clearer   subordinating  nightingale
# 11         hastings     acrylic         virtue             mir        elegy
# 12            laity       tarea        sharpen            scot   mutability
# 13       admonition    validity       activism      searchable          boy
# 14     governmental   dominance      consensus            maid         hath
# 15         felicity         fee    convocation          ticket        vista
# 16          heretic     collage       puzzling  unsatisfactory      prelude
# 17            synod  proportion      patterned           nurse         noir
# 18            salic         dos         server   fertilization         pope
# 19       archbishop      artist        hanging            dell       geared
#
#       Topic # 99    Topic # 100
# 0        serrano       platform
# 1         patria         driven
# 2        secreto      initially
# 3           dime            foe
# 4    practically          sower
# 5      yesterday      defensive
# 6           soup        parable
# 7       tortilla            jog
# 8       springer         garner
# 9       splendor        leisure
# 10        bolero       enjoying
# 11      tomorrow     bellwether
# 12       amoroso        compete
# 13      heirloom       throwing
# 14  disappearing          stuck
# 15     dejection      companion
# 16         swill           disc
# 17          cash         mailer
# 18     trimester  fertilization
# 19     secretion          naked
#
# [20 rows x 100 columns]

# %%
get_lda_topics(lda_tfidf, num_topics)# without auto, 50 passes
# Out:
#        Topic # 01     Topic # 02    Topic # 03    Topic # 04      Topic # 05  \
# 0             art         canvas         revel        tennis      annotation
# 1    architecture           sept        sacred     admission          canvas
# 2         ancient          proof          york         excel  constitutional
# 3       aesthetic    mathematics      colonial        racket            nick
# 4   socioeconomic  propositional           gay       singles         gallery
# 5       sculpture        proving         press         serve         beneath
# 6     paleolithic       duration        autism      endeavor            muse
# 7      fourteenth      induction           era         court           court
# 8      basketball       cogently          chap           net        escalate
# 9         western         landau   colonialism      unsuited             law
# 10     prehistory          spent           war       scoring             oil
# 11         visual      predicate       history   frustration         supreme
# 12       painting          prove       virtual     biosphere         liberty
# 13    prehistoric   mathematical       penguin  consistently           mason
# 14        kingdom         theory  civilization           wet       president
# 15      exemplify           mart       decline     qualified            laid
# 16     suspension        presume       slavery    incredibly        district
# 17   truthtelling        calculi     scripture         ninth          becker
# 18         memoir        amplify        temple      nitrogen           stake
# 19      dismissal         proved        coward    phosphorus            loan
#
#          Topic # 06      Topic # 07      Topic # 08         Topic # 09  \
# 0              chap       athletics          vector                tai
# 1           reliant            golf        calculus                chi
# 2           condone          ethics        likewise              skill
# 3           deathly            mill          canvas            workout
# 4         exceeding  utilitarianism     homogeneous              arrow
# 5            borrow          morals        ordinary  cardiorespiratory
# 6           mixture         ethical  unsatisfactory               gong
# 7           figured       shamanism    differential        interviewee
# 8           chamber       grounding         nucleus           practice
# 9           vitamin            meta      registered      indeterminate
# 10       instrument     metaphysics        singular       prescription
# 11  instrumentation       genealogy      orthogonal               form
# 12          solvent        morality       nonlinear            aerobic
# 13         compiler           moral          solely             enlace
# 14              gas        chipping        geometry               yang
# 15          overlap        concrete    undetermined            dietary
# 16           nickel             soc          sphere              barth
# 17         everyday      commentary           space         meditation
# 18       naturalist            grip          soviet             lonely
# 19        dependent    predeparture           probe              funny
#
#        Topic # 10     ...        Topic # 91    Topic # 92     Topic # 93  \
# 0           smart     ...           candler           cap     governance
# 1        rhythmic     ...             earth        potter       deletion
# 2            hart     ...           geology         harry     restricted
# 3          overly     ...               lab      daughter          scene
# 4        scissors     ...          geologic      sorcerer         acting
# 5           kerry     ...             plate  compensation     successive
# 6          deadly     ...      notification        roster         crises
# 7          lawyer     ...           igneous   discourtesy       nowadays
# 8             flu     ...               yes         ender         belong
# 9      informally     ...         tectonics         stone         import
# 10     intolerant     ...       sedimentary        heaven          steep
# 11        teenage     ...       metamorphic     concealed    subjunctive
# 12      courtroom     ...          humanism          ante         reader
# 13        lactose     ...           lecture         frase    consequence
# 14  typographical     ...        weathering      quarters         permit
# 15        verdict     ...           mineral      exertion      monologue
# 16        slashed     ...        laboratory       upstate  imaginatively
# 17           momo     ...          confront         maize      proximity
# 18          infer     ...            planet         nancy      intuition
# 19         cheese     ...         evolution         viral      strenuous
#
#          Topic # 94  Topic # 95     Topic # 96      Topic # 97   Topic # 98  \
# 0            refute      studio     leadership             doc          ode
# 1         comprised     drawing         prince   administrator      chimney
# 2          fidelity    critique  interpersonal        annotate    innocence
# 3   institutionally       color      conducive         soprano         poet
# 4            annals    painting      sociology          ticket     browning
# 5           dispute         art   sociological          deceit         lamb
# 6       destruction      strong         dining        brochure        blake
# 7              otto         con           spur  unsatisfactory      sweeper
# 8          temporal        para      leviathan           nurse    beauteous
# 9       inquisition        leer     antibiotic     attributive   melancholy
# 10       confession    charcoal           ease        genitive        abbey
# 11          collier     texture     touchstone          wetter      skylark
# 12         hastings         las        clearer           lover   churchyard
# 13       admonition       paint         virtue   subordinating  nightingale
# 14            laity      artist      character             mir        elegy
# 15     governmental  repetition        imagine            scot         gray
# 16         felicity      render       printing      searchable          boy
# 17          heretic       value    interesting            maid   mutability
# 18            mimic       media           sort   fertilization         wind
# 19       archbishop         fee    convocation            dell         hath
#
#       Topic # 99 Topic # 100
# 0        serrano   companion
# 1         patria    platform
# 2           cash      driven
# 3        secreto   initially
# 4           dime       stuck
# 5    practically   defensive
# 6      yesterday         foe
# 7        eclipse       sower
# 8       tortilla        disc
# 9           soup     parable
# 10      springer    throwing
# 11      splendor         jog
# 12        bolero      garner
# 13      tomorrow     leisure
# 14       amoroso    enjoying
# 15      heirloom     compete
# 16  disappearing  bellwether
# 17     dejection        shin
# 18         swill      soccer
# 19         urine       naked
#
# [20 rows x 100 columns]

# %%
len(corpus_used)
# Out:
# 4102
