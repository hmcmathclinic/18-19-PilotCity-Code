# %%
import pandas as pd;
import numpy as np;
import scipy as sp;
import sklearn;
import sys;
from nltk.corpus import stopwords;
import nltk;
from gensim.models import ldamodel
import gensim.corpora;
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer;
from sklearn.decomposition import NMF;
from sklearn.preprocessing import normalize;
from gensim import corpora, models
import pickle;

# %%
import csv
import re
#import spacy
import sys
import requests
import pandas as pd
from io import StringIO
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfpage import PDFTextExtractionNotAllowed
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice
import os
import sys, getopt
import numpy as np
from bs4 import BeautifulSoup
import urllib3
from glob import glob
from string import punctuation

from nltk.corpus import wordnet

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

def find_pdfs():
    return glob(os.path.join('./AllSyllabiParser',"*.{}".format('pdf')))

def convert(fname, pages=None):
    """ Function converting pdf to string """
    if not pages:
        pagenums = set()
    else:
        pagenums = set(pages)

    output = StringIO()
    manager = PDFResourceManager()
    converter = TextConverter(manager, output, laparams=LAParams())
    interpreter = PDFPageInterpreter(manager, converter)

    infile = open(fname, 'rb')
    
    try:
        for page in PDFPage.get_pages(infile, pagenums):
            interpreter.process_page(page)
    except PDFTextExtractionNotAllowed:
        print('This pdf won\'t allow text extraction!')
    infile.close()
    converter.close()
    text = output.getvalue()
    output.close
    return strip_punctuation(text)

def word_count(string):
    my_string = string.lower().split()
    my_dict = {}
    for item in my_string:
        if item in my_dict:
            my_dict[item] += 1
        else:
            my_dict[item] = 1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7e498be8a212> in <module>()
#       6 import pandas as pd
#       7 from io import StringIO
# ----> 8 from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
#       9 from pdfminer.converter import TextConverter
#      10 from pdfminer.layout import LAParams
#
# ModuleNotFoundError: No module named 'pdfminer'

# %%
list_of_pdfs = find_pdfs()
syllabus_string = ''
bag_of_words_all_syllabi = []
corpus = []
#Converting pdf to string
for pdf in list_of_pdfs:
    syllabus_string = convert(pdf)
    corpus.append(syllabus_string)
#     bag_of_words_one_syllabus = word_count(syllabus_string)
#     bag_of_words_all_syllabi.append(bag_of_words_one_syllabus)
# Out:
# This pdf won't allow text extraction!

# %%
# clean text

from nltk.corpus import words
from nltk.corpus import stopwords
 

allEnglishWords = set(words.words())
stopwordsList = set(stopwords.words('english'))

def clean_doc(doc, english = False, return_list = False, stopwords = False):
    listOfWords = re.findall(r'[^\d\W]{2,}', doc)
    listOfWords = [word.lower() for word in listOfWords]
    if english:
        listOfWords = [word for word in listOfWords if word in allEnglishWords]
    if stopwords:
        listOfWords = [word for word in listOfWords if word not in stopwordsList]
    if return_list:
        return listOfWords
    else:
        return " ".join(listOfWords)

# %%
cleaned_corpus = [clean_doc(doc, return_list = True, stopwords = True) for doc in corpus]

# %%
cleaned_corpus_1 = [clean_doc(doc, english = True, return_list = True, stopwords = True) for doc in corpus]

# %%
cleaned_corpus_2 = [clean_doc(doc, english = True, return_list = False, stopwords = True) for doc in corpus]

# %%
cleaned_corpus_3 = [clean_doc(doc, english = False, return_list = False, stopwords = True) for doc in corpus]

# %%
cleaned_corpus_4 = [clean_doc(doc, english = False, return_list = True, stopwords = True) for doc in corpus]

# %%
vectorizer = CountVectorizer(analyzer='word', stop_words='english', lowercase=True, token_pattern=r'[^\d\W]{2,}');
x_counts = vectorizer.fit_transform(cleaned_corpus_2);

# %%
words = vectorizer.get_feature_names()
words
# Out:
# ['aa',
#  'abduction',
#  'aberration',
#  'abide',
#  'ability',
#  'able',
#  'abnormal',
#  'abreast',
#  'abroad',
#  'absence',
#  'absent',
#  'absenteeism',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'absorption',
#  'abstract',
#  'abstracted',
#  'abstraction',
#  'abstractly',
#  'abundance',
#  'abundant',
#  'abuse',
#  'academic',
#  'academically',
#  'academy',
#  'accelerate',
#  'accelerated',
#  'acceleration',
#  'accelerometer',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'acceptor',
#  'access',
#  'accessibility',
#  'accessible',
#  'accessory',
#  'accident',
#  'accidental',
#  'accommodate',
#  'accommodation',
#  'accompany',
#  'accomplish',
#  'accomplished',
#  'accordance',
#  'according',
#  'accordingly',
#  'account',
#  'accountability',
#  'accountable',
#  'accounting',
#  'accreditation',
#  'accrual',
#  'accrue',
#  'accumulate',
#  'accumulation',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'acetylation',
#  'achieve',
#  'achievement',
#  'acid',
#  'acidification',
#  'acoustical',
#  'acquaint',
#  'acquainted',
#  'acquire',
#  'acquired',
#  'acquisition',
#  'acrylic',
#  'act',
#  'actin',
#  'acting',
#  'action',
#  'activation',
#  'active',
#  'actively',
#  'activity',
#  'actual',
#  'actually',
#  'acuity',
#  'ad',
#  'adapt',
#  'adaptability',
#  'adaptable',
#  'adaptation',
#  'adaptive',
#  'adaptively',
#  'add',
#  'added',
#  'addendum',
#  'addicted',
#  'addiction',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'adenosine',
#  'adequate',
#  'adequately',
#  'adhere',
#  'adherence',
#  'adjunct',
#  'adjust',
#  'adjustable',
#  'adjustment',
#  'administration',
#  'administrative',
#  'administratively',
#  'admission',
#  'admittance',
#  'adolescence',
#  'adolescent',
#  'adopt',
#  'adoption',
#  'adult',
#  'adulthood',
#  'advance',
#  'advanced',
#  'advancement',
#  'advantage',
#  'advantageous',
#  'adventure',
#  'adverse',
#  'adversely',
#  'advertisement',
#  'advertising',
#  'advice',
#  'advise',
#  'advised',
#  'advisement',
#  'advisor',
#  'advisory',
#  'advocacy',
#  'ae',
#  'aerobic',
#  'aerodynamics',
#  'aeronautics',
#  'aesthetic',
#  'aesthetics',
#  'affect',
#  'affected',
#  'affecting',
#  'affluence',
#  'afford',
#  'affordable',
#  'afraid',
#  'afterlife',
#  'aftermath',
#  'afternoon',
#  'age',
#  'agency',
#  'agenda',
#  'agent',
#  'aggregate',
#  'aggregation',
#  'aggression',
#  'aggressive',
#  'agile',
#  'aging',
#  'agitation',
#  'ago',
#  'agree',
#  'agreed',
#  'agreement',
#  'agricultural',
#  'agriculture',
#  'ahead',
#  'ai',
#  'aid',
#  'ailing',
#  'aim',
#  'air',
#  'aircraft',
#  'airfoil',
#  'airway',
#  'aka',
#  'al',
#  'alcohol',
#  'alert',
#  'algae',
#  'algal',
#  'algebra',
#  'algebraic',
#  'algebraically',
#  'algorithm',
#  'algorithmic',
#  'alignment',
#  'alike',
#  'alive',
#  'alkyl',
#  'allan',
#  'allele',
#  'allergic',
#  'alliance',
#  'allied',
#  'alligator',
#  'allocate',
#  'allocation',
#  'allow',
#  'allowance',
#  'alongside',
#  'alpha',
#  'alter',
#  'alteration',
#  'alternate',
#  'alternating',
#  'alternation',
#  'alternative',
#  'alternatively',
#  'amazing',
#  'ambient',
#  'amendment',
#  'amentum',
#  'amino',
#  'ammeter',
#  'ample',
#  'amplify',
#  'amplitude',
#  'amputation',
#  'amy',
#  'ana',
#  'anabolism',
#  'anaerobic',
#  'analyses',
#  'analysis',
#  'analyst',
#  'analytic',
#  'analytical',
#  'analytically',
#  'analytics',
#  'analyze',
#  'analyzer',
#  'anatomical',
#  'anatomy',
#  'ancient',
#  'android',
#  'anemia',
#  'aneuploidy',
#  'anger',
#  'angioplasty',
#  'angle',
#  'angry',
#  'angular',
#  'animal',
#  'animated',
#  'animation',
#  'ankle',
#  'ann',
#  'anna',
#  'annex',
#  'annexation',
#  'annotation',
#  'announce',
#  'announcement',
#  'annoying',
#  'annual',
#  'anonymous',
#  'anonymously',
#  'answer',
#  'ant',
#  'anthropology',
#  'antibiotic',
#  'antibody',
#  'anticipate',
#  'antigen',
#  'antitrust',
#  'anxiety',
#  'apa',
#  'apart',
#  'apex',
#  'apostrophe',
#  'apparatus',
#  'apparent',
#  'appeal',
#  'appealing',
#  'appear',
#  'appearance',
#  'appeasing',
#  'appendicular',
#  'apple',
#  'appliance',
#  'applicability',
#  'applicable',
#  'applicant',
#  'application',
#  'applied',
#  'apply',
#  'appointment',
#  'appraise',
#  'appreciate',
#  'appreciation',
#  'apprehension',
#  'apprentice',
#  'apprenticeship',
#  'approach',
#  'approachable',
#  'approaching',
#  'appropriate',
#  'appropriately',
#  'appropriateness',
#  'approval',
#  'approximate',
#  'approximately',
#  'approximation',
#  'aqueous',
#  'ar',
#  'arc',
#  'archaic',
#  'architect',
#  'architectural',
#  'architecture',
#  'area',
#  'arena',
#  'argue',
#  'argument',
#  'argumentative',
#  'arise',
#  'arithmetic',
#  'arithmetical',
#  'arm',
#  'armed',
#  'arms',
#  'army',
#  'aromatic',
#  'arrange',
#  'array',
#  'arrest',
#  'arrival',
#  'arrive',
#  'art',
#  'article',
#  'articulate',
#  'articulation',
#  'artificial',
#  'artificially',
#  'artist',
#  'ascension',
#  'aseptic',
#  'asexual',
#  'ask',
#  'asp',
#  'aspect',
#  'assassination',
#  'assault',
#  'assay',
#  'assemble',
#  'assembly',
#  'assertive',
#  'assertiveness',
#  'assess',
#  'assessed',
#  'assessment',
#  'asset',
#  'assets',
#  'assign',
#  'assigned',
#  'assignment',
#  'assimilate',
#  'assist',
#  'assistance',
#  'assistant',
#  'assistive',
#  'associate',
#  'associated',
#  'association',
#  'assorted',
#  'assortment',
#  'assume',
#  'assumed',
#  'assuming',
#  'assumption',
#  'assure',
#  'ast',
#  'asthma',
#  'astigmatism',
#  'astronomy',
#  'asynchronous',
#  'athlete',
#  'athletic',
#  'atlas',
#  'atmosphere',
#  'atmospheric',
#  'atom',
#  'atomic',
#  'atomics',
#  'atop',
#  'attach',
#  'attached',
#  'attachment',
#  'attack',
#  'attain',
#  'attainment',
#  'attempt',
#  'attend',
#  'attendance',
#  'attention',
#  'attired',
#  'attitude',
#  'attract',
#  'attractive',
#  'attributable',
#  'attribute',
#  'attribution',
#  'audacity',
#  'audience',
#  'audio',
#  'audiogram',
#  'audit',
#  'auditory',
#  'august',
#  'aunt',
#  'authentic',
#  'authentication',
#  'author',
#  'authority',
#  'authorization',
#  'authorize',
#  'authorized',
#  'automatic',
#  'automatically',
#  'automobile',
#  'autonomic',
#  'autonomous',
#  'autopilot',
#  'autopsy',
#  'autosome',
#  'autotroph',
#  'auxiliary',
#  'avail',
#  'availability',
#  'available',
#  'ave',
#  'average',
#  'avoid',
#  'avoidance',
#  'award',
#  'aware',
#  'awareness',
#  'away',
#  'awesome',
#  'axial',
#  'axis',
#  'axle',
#  'ba',
#  'baby',
#  'bacillus',
#  'backbone',
#  'background',
#  'backlash',
#  'backup',
#  'bacteria',
#  'bacterial',
#  'bacteriology',
#  'bacterium',
#  'bad',
#  'bade',
#  'bake',
#  'balance',
#  'balanced',
#  'balancing',
#  'ball',
#  'bank',
#  'banked',
#  'banking',
#  'bar',
#  'baroque',
#  'barrier',
#  'base',
#  'based',
#  'bases',
#  'basic',
#  'basically',
#  'basis',
#  'basketball',
#  'battery',
#  'battle',
#  'beam',
#  'bear',
#  'beard',
#  'beautiful',
#  'beauty',
#  'beck',
#  'beer',
#  'begging',
#  'begin',
#  'beginning',
#  'begun',
#  'behalf',
#  'behave',
#  'behavior',
#  'behavioral',
#  'belief',
#  'believe',
#  'belong',
#  'belonging',
#  'beneficial',
#  'benefit',
#  'benjamin',
#  'benthic',
#  'benzene',
#  'ber',
#  'best',
#  'bet',
#  'better',
#  'beverage',
#  'beware',
#  'bibliographic',
#  'bibliography',
#  'bicycle',
#  'big',
#  'biggest',
#  'billboard',
#  'billion',
#  'binary',
#  'binder',
#  'binding',
#  'binomial',
#  'biochemical',
#  'biochemistry',
#  'biographical',
#  'biological',
#  'biologically',
#  'biology',
#  'biometrics',
#  'biopsychology',
#  'bios',
#  'biosphere',
#  'biosynthesis',
#  'birth',
#  'birthday',
#  'bit',
#  'bite',
#  'bivariate',
#  'black',
#  'blackboard',
#  'blank',
#  'blanket',
#  'blastula',
#  'blending',
#  'blessing',
#  'blind',
#  'blink',
#  'blinking',
#  'block',
#  'blocked',
#  'blocking',
#  'blood',
#  'bloodstain',
#  'blue',
#  'board',
#  'boat',
#  'body',
#  'bond',
#  'bonding',
#  'bone',
#  'bonus',
#  'bony',
#  'book',
#  'bookkeeping',
#  'bookstore',
#  'boost',
#  'border',
#  'borderline',
#  'borer',
#  'born',
#  'borrow',
#  'bot',
#  'bother',
#  'bottle',
#  'bottled',
#  'bought',
#  'bouncing',
#  'bound',
#  'boundless',
#  'bountiful',
#  'box',
#  'brachial',
#  'bracket',
#  'brain',
#  'brains',
#  'branch',
#  'branching',
#  'brand',
#  'breadboard',
#  'breadth',
#  'break',
#  'breakdown',
#  'breaking',
#  'breast',
#  'breath',
#  'breathing',
#  'breed',
#  'brent',
#  'brief',
#  'briefly',
#  'bright',
#  'bring',
#  'broad',
#  'brochure',
#  'broken',
#  'brother',
#  'brought',
#  'browser',
#  'browsing',
#  'brushes',
#  'bud',
#  'buddy',
#  'budget',
#  'buffer',
#  'build',
#  'building',
#  'built',
#  'bulk',
#  'bundle',
#  'bung',
#  'bungle',
#  'buoyancy',
#  'burden',
#  'bureaucracy',
#  'bureaucratic',
#  'burglary',
#  'buried',
#  'burn',
#  'burned',
#  'burnout',
#  'burst',
#  'business',
#  'busy',
#  'button',
#  'buttons',
#  'buy',
#  'ca',
#  'cad',
#  'cadaver',
#  'calcified',
#  'calcium',
#  'calculate',
#  'calculated',
#  'calculating',
#  'calculation',
#  'calculator',
#  'calculus',
#  'calendar',
#  'calibration',
#  'calipers',
#  'calling',
#  'calorimetry',
#  'cam',
#  'camera',
#  'camp',
#  'campus',
#  'canal',
#  'cancel',
#  'cancellation',
#  'cancer',
#  'cancerous',
#  'canine',
#  'cannon',
#  'canvas',
#  'canvass',
#  'cap',
#  'capable',
#  'capacitance',
#  'capacitive',
#  'capacitor',
#  'capacity',
#  'capital',
#  'capitalization',
#  'capsize',
#  'capstone',
#  'capture',
#  'car',
#  'carbohydrate',
#  'carbon',
#  'carbonless',
#  'carboxylic',
#  'card',
#  'cardiac',
#  'cardiopulmonary',
#  'cardiovascular',
#  'care',
#  'career',
#  'careful',
#  'carefully',
#  'careless',
#  'carelessness',
#  'caret',
#  'carman',
#  'carried',
#  'carry',
#  'carrying',
#  'carte',
#  'cartel',
#  'carter',
#  'case',
#  'cash',
#  'casual',
#  'cat',
#  'catalase',
#  'catalyst',
#  'catch',
#  'catching',
#  'catchy',
#  'categorical',
#  'category',
#  'caught',
#  'causation',
#  'cause',
#  'causing',
#  'cavalryman',
#  'ce',
#  'cease',
#  'ceiling',
#  'cell',
#  'celled',
#  'cellular',
#  'cellulosic',
#  'center',
#  'centered',
#  'central',
#  'centriole',
#  'centripetal',
#  'century',
#  'ceramic',
#  'ceramics',
#  'cerebral',
#  'certain',
#  'certificate',
#  'certification',
#  'certified',
#  'cess',
#  'cessation',
#  'chain',
#  'chair',
#  'challenge',
#  'challenger',
#  'chance',
#  'chancellor',
#  'change',
#  'channel',
#  'chaos',
#  'chapter',
#  'character',
#  'characteristic',
#  'characterize',
#  'charge',
#  'charging',
#  'chart',
#  'chat',
#  'chatting',
#  'cheat',
#  'cheating',
#  'check',
#  'checked',
#  'cheek',
#  'chemical',
#  'chemistry',
#  'chemotherapy',
#  'chest',
#  'chick',
#  'chief',
#  'child',
#  'childhood',
#  'china',
#  'chirality',
#  'chloroplast',
#  'choice',
#  'choking',
#  'cholesterol',
#  'chondroitin',
#  'choose',
#  'choosing',
#  'chosen',
#  'chromatin',
#  'chromatographic',
#  'chromatography',
#  'chrome',
#  'chromosomal',
#  'chromosome',
#  'chronic',
#  'chronological',
#  'chunk',
#  'church',
#  'cilia',
#  'circa',
#  'circle',
#  'circuit',
#  'circular',
#  'circulation',
#  'circulatory',
#  'circumference',
#  'circumstance',
#  'cisco',
#  'citation',
#  'cite',
#  'citizen',
#  'citizenship',
#  'citric',
#  'city',
#  'civic',
#  'civics',
#  'civil',
#  'civilian',
#  'civility',
#  'civilization',
#  'civilized',
#  'claim',
#  'clap',
#  'clarification',
#  'clarify',
#  'clarity',
#  'class',
#  'classes',
#  'classic',
#  'classical',
#  'classification',
#  'classmate',
#  'classroom',
#  'classwork',
#  'clay',
#  'clean',
#  'cleaning',
#  'cleanliness',
#  'cleanup',
#  'clear',
#  'clearing',
#  'clearly',
#  'cleavage',
#  'click',
#  'client',
#  'climate',
#  'clinic',
#  'clinical',
#  'clip',
#  'clips',
#  'clock',
#  'clocked',
#  'clone',
#  'close',
#  'closed',
#  'closely',
#  'closure',
#  'cloth',
#  'clothing',
#  'cloud',
#  'cluster',
#  'coastal',
#  'cochlear',
#  'code',
#  'codon',
#  'coefficient',
#  'cofactor',
#  'cognition',
#  'cognitive',
#  'cognitively',
#  'cognitum',
#  'coherence',
#  'cohesion',
#  'cohesive',
#  'coincide',
#  'cold',
#  'coli',
#  'colin',
#  'collaborate',
#  'collaboration',
#  'collaborative',
#  'collaboratively',
#  'collapse',
#  'collect',
#  'collected',
#  'collection',
#  'collective',
#  'collectively',
#  'college',
#  'colligative',
#  'collision',
#  'collusion',
#  'colonial',
#  'colonialism',
#  'colonization',
#  'color',
#  'colored',
#  'coloring',
#  'colors',
#  'column',
#  'combination',
#  'combinational',
#  'combine',
#  'combined',
#  'combing',
#  'combining',
#  'combustible',
#  'come',
#  'comes',
#  'comfort',
#  'comfortable',
#  'comfortably',
#  'coming',
#  'comma',
#  'command',
#  'commence',
#  'comment',
#  'commerce',
#  'commercial',
#  'commit',
#  'commitment',
#  'committee',
#  'common',
#  'commoner',
#  'commonly',
#  'commons',
#  'commonwealth',
#  'communal',
#  'communicate',
#  'communicating',
#  'communication',
#  'communism',
#  'community',
#  'compact',
#  'companion',
#  'company',
#  'comparable',
#  'comparative',
#  'comparatively',
#  'compare',
#  'comparison',
#  'compartmental',
#  'compass',
#  'compelling',
#  'compete',
#  'competence',
#  'competency',
#  'competent',
#  'competition',
#  'competitive',
#  'competitor',
#  'compilation',
#  'compile',
#  'complement',
#  'complementary',
#  'complete',
#  'completely',
#  'completion',
#  'complex',
#  'complexity',
#  'compliance',
#  'complicated',
#  'complimentary',
#  'comply',
#  'component',
#  'comportment',
#  'compose',
#  'composed',
#  'composite',
#  'composition',
#  'compositional',
#  'compound',
#  'comprehend',
#  'comprehension',
#  'comprehensive',
#  'compressed',
#  'compression',
#  'comprise',
#  'comprised',
#  'compromise',
#  'computation',
#  'computational',
#  'compute',
#  'computer',
#  'conceive',
#  'concentrate',
#  'concentrated',
#  'concentration',
#  'concept',
#  'conception',
#  'conceptual',
#  'concern',
#  'concerned',
#  'concerning',
#  'concession',
#  'concise',
#  'conclude',
#  'concluding',
#  'conclusion',
#  'concrete',
#  'concurrent',
#  'concurrently',
#  'condensed',
#  'condescending',
#  'condition',
#  'conditional',
#  'conducive',
#  'conduct',
#  'conductance',
#  'conduction',
#  'conductive',
#  ...]

# %%
id2word = {}
for i, word in enumerate(words):
    id2word[i] = word

# %%
transformer = TfidfTransformer(smooth_idf=False);
x_tfidf = transformer.fit_transform(x_counts);

# %%
xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

# %%
def get_nmf_topics(model, n_top_words):
    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(num_topics):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-20 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
num_topics = 25
model = NMF(n_components=num_topics, init='nndsvd')
model.fit(xtfidf_norm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0,
#   max_iter=200, n_components=25, random_state=None, shuffle=False,
#   solver='cd', tol=0.0001, verbose=0)

# %%
get_nmf_topics(model, 20)
# Out:
#        Topic # 01   Topic # 02      Topic # 03  Topic # 04   Topic # 05  \
# 0         student  electricity         culture         lab       lesson
# 1      instructor       lesson        language     lecture      medical
# 2           class  electronics  presentational     biology         body
# 3          policy      digital   interpersonal  laboratory      disease
# 4             art      circuit    interpretive        exam      patient
# 5          sexual        magic   communication    genetics        human
# 6          course       design           audio     ecology  investigate
# 7   participation         trip        cultural     organic       murder
# 8      attendance        basic         respond      course      illness
# 9        painting   electronic        speaking     anatomy        crime
# 10     proportion        logic          prompt       fungi        brain
# 11         hybrid        world           print        cell      mystery
# 12      statement    entertain            exam    cellular        scene
# 13           mail     creative          course       final        vital
# 14          title         life       authentic   evolution     diagnose
# 15       handbook     consider            task       grade      explore
# 16       academic    limitless       placement      review        toxin
# 17       semester        realm         variety       plant    detective
# 18        virtual      assumed    conversation        life      nervous
# 19         active         pack        advanced  biological  dysfunction
#
#       Topic # 06    Topic # 07     Topic # 08   Topic # 09  Topic # 10  \
# 0        physics       history  trigonometric       design       class
# 1      magnetism    historical             ti  engineering     chapter
# 2       electric      question   trigonometry      project     student
# 3    electricity      argument    exponential      element      course
# 4         course       explain    logarithmic      process        exam
# 5         motion      relative          polar     solution    learning
# 6     laboratory      evidence       calculus       lesson     college
# 7   introductory         world        algebra     modeling     classes
# 8      mechanics  significance      algebraic         lead  instructor
# 9     scientific        course          angle         unit    computer
# 10      magnetic          exam           math       create  assignment
# 11          lens        period     instructor         page       grade
# 12       college     reasoning    mathematics          way    semester
# 13        charge    continuity        inverse    component        drop
# 14      momentum     secondary       triangle    prototype      center
# 15        energy       primary         course      problem        week
# 16          exam        sample           test    challenge        work
# 17     phenomena         score       geometry   commercial         day
# 18     placement         claim           plus          toy      office
# 19    equivalent         skill          solve      testing      spring
#
#         ...         Topic # 16     Topic # 17     Topic # 18   Topic # 19  \
# 0       ...              space      inflation  architectural        media
# 1       ...             flight       economic   architecture        video
# 2       ...             lesson      aggregate         lesson        audio
# 3       ...           aircraft         supply         design          web
# 4       ...        aeronautics         demand          green   converting
# 5       ...               moon      economics    sustainable      element
# 6       ...             design   unemployment     commercial       course
# 7       ...             travel          money             ga          use
# 8       ...         propulsion         market       shipping     delivery
# 9       ...         atmosphere         fiscal    residential      linking
# 10      ...          traveling       monetary   construction      marking
# 11      ...        engineering        chapter          learn      support
# 12      ...             living  international           home        build
# 13      ...             flying          curve       building     dominant
# 14      ...            history        economy    engineering         file
# 15      ...              earth         policy  environmental           na
# 16      ...         simulation         growth          today     academic
# 17      ...               test          trade         framed          asp
# 18      ...            airfoil         income      container  appropriate
# 19      ...               unit        country    encouraging   disability
#
#        Topic # 20     Topic # 21    Topic # 22      Topic # 23     Topic # 24  \
# 0          health     psychology    statistics             vex         speech
# 1         justice  psychological   probability          python          class
# 2          public          psych      sampling      registered     persuasive
# 3          social           quiz          dogs          resume          round
# 4          course        chapter         joint        inventor         packet
# 5   socioeconomic       complete   statistical          studio         employ
# 6             oer       behavior         score          design       speaking
# 7         unequal         course          data         project  communication
# 8          status       abnormal           hip            lead          group
# 9           class       research      blocking           based    informative
# 10           care            sun        random          create       delivery
# 11         sexual         length   descriptive      reflection        lecture
# 12        tactics     scientific     exploring          course        deliver
# 13     instructor         mental          exam             way         turned
# 14        chronic          worth  distribution  accountability      beginning
# 15          title        initial      variable      foundation           week
# 16      prevalent        mission          test            task        outline
# 17         school            sat        sample           brand           quiz
# 18      insurance    development          math        showcase           post
# 19     infectious     biological     inference     performance   presentation
#
#        Topic # 25
# 0          module
# 1          canvas
# 2      discussion
# 3           ocean
# 4        textbook
# 5            read
# 6           class
# 7            quiz
# 8          course
# 9   international
# 10         marine
# 11     assignment
# 12   oceanography
# 13       midnight
# 14          forum
# 15         sexual
# 16           post
# 17     instructor
# 18     harassment
# 19     accounting
#
# [20 rows x 25 columns]

# %% [markdown]
# **LDA**

# %%
id2word = gensim.corpora.Dictionary(cleaned_corpus_1);
id2word

# %%
bow_corpus = [id2word.doc2bow(doc) for doc in cleaned_corpus_1]

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
corpus_tfidf

# %%
lda = gensim.models.ldamodel.LdaModel(bow_corpus, num_topics=20, id2word=id2word, passes=50)

# %%
lda_tfidf = gensim.models.ldamodel.LdaModel(corpus_tfidf, num_topics=10, id2word=id2word, passes=50)

# %%
def get_lda_topics(model, num_topics):
    word_dict = {};
    for i in range(num_topics):
        words = model.show_topic(i, topn = 20);
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words];
    return pd.DataFrame(word_dict);

# %%
get_lda_topics(lda, 20)
# Out:
#        Topic # 01  Topic # 02     Topic # 03   Topic # 04     Topic # 05  \
# 0             due      course        student       lesson          class
# 1        complete    academic          class       design     discussion
# 2            quiz     student         course         body         please
# 3      psychology      policy     instructor      project         speech
# 4          course  disability         policy         unit         course
# 5         chapter  instructor            may      explore        student
# 6         student    learning     attendance          way       textbook
# 7   psychological        work         sexual         lead           work
# 8           psych       state       academic  investigate           week
# 9      discussion        must         office       course  communication
# 10   introduction     limited  participation         page            due
# 11        college        test         system          use           must
# 12    development  laboratory           time         goal        chapter
# 13            one       order         health      disease           read
# 14     instructor         use       semester        human           time
# 15          worth     another           week        learn          first
# 16         office         may    information      medical          group
# 17     assignment       class           work        water           post
# 18           also        exam      following       system           note
# 19        another   reference        contact      outline    information
#
#    Topic # 06  Topic # 07   Topic # 08     Topic # 09   Topic # 10  \
# 0       class         lab       design        physics     syllabus
# 1     student     lecture  engineering         energy     waymaker
# 2      course      course      project         course       demand
# 3       grade         may         unit        chapter        final
# 4         may        exam       course     experiment        topic
# 5    learning  laboratory      process     laboratory        price
# 6      canvas       class      problem         motion       module
# 7        exam     biology          use            law       supply
# 8         day     student       lesson  understanding        class
# 9        must        cell          way       electric      section
# 10    chapter  instructor         lead          light  competition
# 11      final        must     solution          apply  equilibrium
# 12       week       final         page        circuit     monopoly
# 13   complete       grade        power          force        grade
# 14   homework   structure       energy          field      reading
# 15       drop    chemical     material       magnetic     semester
# 16       last    cellular       create           work   elasticity
# 17     office        life        learn      magnetism     marginal
# 18    section     chapter      control          sound     describe
# 19       test    learning      element          speed   regulation
#
#        Topic # 11    Topic # 12   Topic # 13   Topic # 14 Topic # 15  \
# 0          design        canvas       course        class     system
# 1          lesson      physical      student      student     course
# 2        building         excel          may       course    anatomy
# 3      commercial    assistance        class         work       exam
# 4         project      textbook       design         week      class
# 5     engineering           via   instructor          may      human
# 6    architecture      computer          use        grade   describe
# 7   architectural         shall       lesson   instructor       body
# 8     development     financial          lab        final        lab
# 9            unit        module       system         exam    student
# 10          learn    accounting         exam      chapter  practical
# 11           site       canvass      college      college    medical
# 12    residential       company         work  information    nervous
# 13         course         click     learning     homework    college
# 14          civil         sheet          one     learning       time
# 15         impact       program  information          use        may
# 16   construction       prepare         body         must   skeletal
# 17            way          link      project     academic    lecture
# 18           page           use   laboratory          one        use
# 19            use  conversation         must          lab       must
#
#     Topic # 16     Topic # 17     Topic # 18   Topic # 19   Topic # 20
# 0       course          class         course         days        class
# 1         exam           read          class     activity       course
# 2      history        reading        college       lesson     computer
# 3      college       economic           exam      project  certificate
# 4   historical        writing       language       create          use
# 5        score       homework        student         data     security
# 6     question           week       learning      problem      history
# 7    placement  international    information     computer        learn
# 8      program     assignment            use         page        login
# 9        world      inflation     instructor       course         week
# 10    advanced         course  communication          way         exam
# 11     explain      aggregate            may         unit          day
# 12     develop            mon           work      science          one
# 13         one         supply       business         lead         deep
# 14   political          paper        chapter          use         need
# 15     section        journal         office        learn         work
# 16  government            may       academic  development           eh
# 17      sample   unemployment       computer         code     learning
# 18    politics          money         access          web        click
# 19        part            due        reading         game         take

# %%
get_lda_topics(lda_tfidf, 10)
# Out:
#        Topic # 01   Topic # 02      Topic # 03     Topic # 04    Topic # 05  \
# 0         organic         anna   trigonometric       painting        module
# 1          python     sampling     logarithmic            asp      disabled
# 2       fieldwork     wearable     exponential       subtract         login
# 3          studio   regression        criminal          ocean         refer
# 4     certificate         game    trigonometry         infant      cellular
# 5             vex   estimation          cancer       provider          link
# 6   architectural   conductive        rational    dimensional        speech
# 7        inventor        blink         inverse          adult      attached
# 8           trial     variance      polynomial          slope  differential
# 9     achievement       sickle           polar    association       consent
# 10        statics       bungle   algebraically          child         click
# 11        kinetic     goodness  transcendental         studio       looping
# 12     carboxylic     binomial           limit      pediatric       justice
# 13            pro         pure       quadratic        choking       walking
# 14   nomenclature       random     manipulator         airway       meeting
# 15   announcement     tendency        triangle  demonstration    derivative
# 16       reaction    deviation   indeterminate       duration          sign
# 17      synthetic    economics        analytic  craftsmanship       protein
# 18         intern  exploratory         radical  combinational           mar
# 19        meeting  contingency           smith      challenge   inheritance
#
#       Topic # 06     Topic # 07   Topic # 08   Topic # 09    Topic # 10
# 0   unemployment         supply        movie       lesson        duiker
# 1          money         demand        toxin          lab      waymaker
# 2       monetary      inflation          ing       design    responsive
# 3         fiscal      aggregate       empire      chapter            ad
# 4         rhythm         market         cess        class           tum
# 5    expenditure      economics    cognition   laboratory       machine
# 6        banking          trade          car      lecture        layout
# 7        excerpt  international      decline   instructor            ut
# 8    negotiation         matrix      hearing      student           cum
# 9         melody         income     majority      project         prose
# 10        parkin        economy   prehistory       sexual        poetry
# 11          bade          price          ber       policy      infinite
# 12    multiplier             eh     headline         unit  resubmission
# 13       wartime          goods          gra      physics           dis
# 14     whitehead        hostile           ly         exam        sharps
# 15       billion           deep        avail      history      improper
# 16        mostly    competition         yond  engineering            ar
# 17      revision       monopoly         prob       health          pick
# 18  inflationary     elasticity        drink       energy        double
# 19            el         module  mesopotamia      culture       torture

# %%
get_lda_topics(lda, 20)
# Out:
#         Topic # 01  Topic # 02    Topic # 03        Topic # 04     Topic # 05  \
# 0           course      course      inserted             music         course
# 1             exam      health  hypothetical             redox        student
# 2         language       class         shark        equilibria          class
# 3          college    syllabus       dioxide       colligative       learning
# 4          culture       grade         crude             ionic            may
# 5            score     student         plate  electrochemistry        physics
# 6    communication  instructor   culmination           process           must
# 7         advanced  assignment    downstream             worth           work
# 8        placement      public      humanity       dissolution       complete
# 9          program      social       cooking            scales        college
# 10           world       final      digested                ex  communication
# 11   interpersonal         one        septic            assign            day
# 12         section    waymaker        edible        cumulative          first
# 13           audio    learning         comes              weak    information
# 14  presentational     justice         water           penalty            use
# 15            part      please        course        additional         please
# 16           study      office      polluted              left           exam
# 17           based      spring    biological      mathematical           last
# 18         element     college          food             sound           drop
# 19         respond    complete        lesson           fission          grade
#
#      Topic # 06  Topic # 07  Topic # 08   Topic # 09     Topic # 10  \
# 0        course      course  accounting       design         course
# 1         class  laboratory       class       lesson           text
# 2       student         may     chapter  engineering        reading
# 3           use    academic     student      project       language
# 4           may     chapter      course         unit     literature
# 5          exam         lab        exam       energy           exam
# 6      language        must  instructor          way  communication
# 7        lesson      policy   financial      process        culture
# 8           lab     student     subject          use       literary
# 9       college    learning        work         lead          study
# 10      project        exam    homework         page        college
# 11     learning  disability     connect       course      listening
# 12         days  instructor      please      problem        develop
# 13   instructor       state      change        water           list
# 14         page     limited  understand        learn            may
# 15         must       grade        date     building          works
# 16  information        work      canvas     solution          short
# 17      lecture     another         use      outline          score
# 18          one       order        time   commercial       cultural
# 19     computer  experiment         due        power        program
#
#      Topic # 11   Topic # 12  Topic # 13     Topic # 14     Topic # 15  \
# 0          body        class       class         course        student
# 1        lesson       speech      course           math          class
# 2         human       course         due           test         course
# 3       history      student     history     instructor     instructor
# 4   investigate      chapter     chapter         linear         policy
# 5       disease   instructor    complete  trigonometric            may
# 6       medical          use     reading    mathematics     attendance
# 7        course          may        quiz             ti  participation
# 8       explore      college     student          solve       academic
# 9    historical     learning       paper     disability           time
# 10      analyze         week         one       academic         office
# 11      project         work         may         review       semester
# 12       health         must     writing        algebra         sexual
# 13        heart  information  discussion       calculus           work
# 14          use     language  assignment           work    information
# 15         work        first        also       learning           week
# 16         anna        group        exam           real            art
# 17          way         page        week    exponential      following
# 18         lead     computer        work          order            two
# 19        blood     academic    textbook          state    demonstrate
#
#       Topic # 16   Topic # 17   Topic # 18   Topic # 19     Topic # 20
# 0     government       lesson       course          lab       economic
# 1      political         days        class      lecture           read
# 2       politics      project      student      biology         policy
# 3             us     activity         exam         exam         course
# 4         course       design   instructor         cell       textbook
# 5           exam       create          may     cellular         supply
# 6            one       course      college          may          class
# 7        explain         data       system       course         demand
# 8         system         unit         week         life         sexual
# 9         united          way     learning   laboratory     discussion
# 10   comparative         page         work        class  international
# 11       analyze         lead  information    structure     harassment
# 12  constitution          use        grade      control      economics
# 13           two     computer       office     genetics         market
# 14         court      problem          use        final        student
# 15        school        learn        final      protein         canvas
# 16      analysis      science         time      student      inflation
# 17         civil         goal         must     function      aggregate
# 18       college      explore       please     semester          money
# 19       supreme  development     academic  inheritance   unemployment

# %%
get_lda_topics(lda_tfidf, 10)
# Out:
#        Topic # 01   Topic # 02   Topic # 03        Topic # 04     Topic # 05  \
# 0          lesson          war  comparative         marketing     psychology
# 1          speech      ecology        trial            cancer          psych
# 2            game   revolution    fieldwork                ba            asp
# 3          python     religion     wearable            rhythm         lesson
# 4          mobile         poem       intern           ecology       criminal
# 5      psychology        fungi       market           musical         infant
# 6           movie      wartime       demand             fungi          child
# 7        inventor    whitehead        robot              dogs          heart
# 8    installation      billion      execute  entrepreneurship       provider
# 9             pro      despite   conductive             joint  psychological
# 10  psychological          doe        blink           sheriff          crime
# 11      interface  extenuating     alliance              mike          adult
# 12    abstraction    glassware          sub         treatment    association
# 13    collaborate          men     inactive            scales         allied
# 14      authentic      perhaps        digit             smith         murder
# 15        preface   nineteenth       supply          blocking         health
# 16   civilization   indication         pure               hip        choking
# 17  certification     educated       profit             buddy      pediatric
# 18      prototype       damned        trade              seed         airway
# 19        android   automobile     discount         infection        initial
#
#        Topic # 06      Topic # 07     Topic # 08     Topic # 09  \
# 0             lab         physics         lesson         health
# 1          design  presentational         duiker         lesson
# 2         chapter          motion  architectural           body
# 3           class          lesson    diffraction       skeletal
# 4      laboratory    interpretive   architecture        anatomy
# 5         lecture         culture        nuclear        justice
# 6      instructor     electricity     commercial         matrix
# 7         student        electric          audio       waymaker
# 8         project   interpersonal           prof         flight
# 9          sexual           audio    radioactive             eh
# 10         policy       magnetism           mill     anatomical
# 11           unit        magnetic          stamp       aircraft
# 12           exam           light    residential       muscular
# 13        history           force           sons         supply
# 14    engineering      literature          robot           deep
# 15         energy     electronics    sustainable       skeleton
# 16        biology       mechanics          green     dissection
# 17            art          prompt        formula    calibration
# 18          grade            wave       passport  socioeconomic
# 19  participation            heat            raw            oer
#
#         Topic # 10
# 0        inflation
# 1        aggregate
# 2     unemployment
# 3           lesson
# 4           supply
# 5            money
# 6              vex
# 7         monetary
# 8           fiscal
# 9             anna
# 10        assembly
# 11          demand
# 12      responsive
# 13         disease
# 14         economy
# 15          resume
# 16          folder
# 17  capitalization
# 18           heart
# 19        midnight

# %% [markdown]
# **New LDA Library**

# %%
import lda
from sklearn.feature_extraction.text import CountVectorizer

# %%
cvectorizer = CountVectorizer(min_df=5, stop_words='english')
cvz = cvectorizer.fit_transform(cleaned_corpus_3)

# %%
n_topics = 20
n_iter = 20



lda_m = lda.LDA(n_topics=n_topics, n_iter=n_iter)
X_topics = lda_m.fit_transform(cvz)
# Out:
# INFO:lda:n_documents: 156
# INFO:lda:vocab_size: 2832
# INFO:lda:n_words: 125458
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 20
# WARNING:lda:all zero row in document-term matrix found
# C:\Users\Public\Anaconda3\lib\site-packages\lda\utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:<0> log likelihood: -1399328
# INFO:lda:<10> log likelihood: -969903
# INFO:lda:<19> log likelihood: -932084

# %%
lda_m.topic_word_
# Out:
# array([[2.09103531e-06, 1.33847170e-02, 2.51133341e-03, ...,
#         2.09103531e-06, 2.09103531e-06, 2.09103531e-06],
#        [1.73390760e-06, 1.73390760e-06, 2.42920455e-03, ...,
#         1.73390760e-06, 1.73390760e-06, 1.73390760e-06],
#        [1.91632556e-06, 1.91632556e-06, 1.91632556e-06, ...,
#         1.91632556e-06, 1.91632556e-06, 1.91632556e-06],
#        ...,
#        [1.29595455e-06, 1.29595455e-06, 1.29595455e-06, ...,
#         1.29595455e-06, 1.29595455e-06, 1.29595455e-06],
#        [1.89669823e-06, 1.89669823e-06, 1.89669823e-06, ...,
#         1.89669823e-06, 1.89669823e-06, 1.89669823e-06],
#        [1.64871763e-06, 1.64871763e-06, 1.64871763e-06, ...,
#         1.64871763e-06, 1.65036635e-03, 3.13421221e-03]])

# %%
vocab

# %%
 # model.components_ also works
vocab = gensim.corpora.Dictionary(cleaned_corpus_4)    
    
topic_word = lda_m.topic_word_
n_top_words = 8
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    print('Topic {}: {}'.format(i, ' '.join(topic_words)))
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:built Dictionary(10958 unique tokens: ['academic', 'adaptively', 'addressed', 'advice', 'allowed']...) from 156 documents (total 153738 corpus positions)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-3134ac69e9c3> in <module>()
#       6 for i, topic_dist in enumerate(topic_word):
#       7    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
# ----> 8    print('Topic {}: {}'.format(i, ' '.join(topic_words)))
#
# TypeError: sequence item 0: expected str instance, numpy.int32 found
